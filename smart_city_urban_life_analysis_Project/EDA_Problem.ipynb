# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dc = pd.read_csv(r"C:\Users\Anish Kumar\OneDrive\Documents\GitHub\PANDAS-CURSE\smart_city_urban_life_analysis_Project\cleaned_data.csv")

# %%
dc.head(5)
# Out:
#    Record_ID        Date   Day_Name       City    Area_Type Citizen_ID  \
# 0  REC000001  2024-07-17  Wednesday     Mumbai  Residential  CIT356787
# 1  REC000002  2025-01-05     Sunday     Mumbai  Residential  CIT988662
# 2  REC000003  2024-12-28   Saturday  Hyderabad  Residential  CIT319684
# 3  REC000004  2023-10-13     Friday     Jaipur  Residential  CIT358607
# 4  REC000005  2023-08-23  Wednesday      Delhi   Commercial  CIT814825
#
#   Age_Group Work_Mode  Temperature_C  Rainfall_mm  ...  Work_Hours  \
# 0     25-34    Office           31.4          0.7  ...        10.2
# 1     25-34    Hybrid           21.2          2.5  ...         6.2
# 2     35-44    Office           20.6          2.0  ...         8.3
# 3     35-44     Other           21.8          0.5  ...         0.5
# 4     45-54    Hybrid           29.3          2.8  ...         7.0
#
#   Outdoor_Activity_Hours  Happiness_Score Service_Satisfaction  Weekend  \
# ...

# %%
dc.tail(5)
# Out:
#        Record_ID        Date  Day_Name       City    Area_Type Citizen_ID  \
# 99995  REC099996  2025-11-21    Friday    Chennai   Industrial  CIT227256
# 99996  REC099997  2023-05-26    Friday  Bengaluru  Residential  CIT834022
# 99997  REC099998  2024-10-27    Sunday    Kolkata    Mixed Use  CIT455598
# 99998  REC099999  2023-09-14  Thursday    Chennai    Mixed Use  CIT721668
# 99999  REC100000  2025-12-04  Thursday  Hyderabad  Residential  CIT170780
#
#       Age_Group       Work_Mode  Temperature_C  Rainfall_mm  ...  Work_Hours  \
# 99995     18-24          Hybrid           27.0          3.4  ...         8.9
# 99996     45-54  Work From Home           28.5          0.2  ...         6.1
# 99997     18-24           Other           24.3          2.7  ...         3.0
# 99998     18-24          Office           30.5          0.5  ...         7.8
# 99999     18-24          Hybrid           23.3          1.8  ...         6.8
#
# ...

# %%
dc.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Record_ID                       100000 non-null  str
#  1   Date                            100000 non-null  str
#  2   Day_Name                        100000 non-null  str
#  3   City                            100000 non-null  str
#  4   Area_Type                       100000 non-null  str
#  5   Citizen_ID                      100000 non-null  str
#  6   Age_Group                       100000 non-null  str
#  7   Work_Mode                       100000 non-null  str
#  8   Temperature_C                   100000 non-null  float64
#  9   Rainfall_mm                     100000 non-null  float64
#  10  AQI                             100000 non-null  float64
#  11  Traffic_Level                   100000 non-null  str
# ...

# %%
dc.describe()
# Out:
#        Temperature_C    Rainfall_mm            AQI  Average_Traffic_Speed_kmh  \
# count  100000.000000  100000.000000  100000.000000              100000.000000
# mean       27.122641       3.664261     115.652720                  27.924011
# std         5.535933       5.653815      47.424984                  13.508682
# min         6.800000       0.000000      20.000000                   4.000000
# 25%        23.000000       0.600000      82.000000                  16.200000
# 50%        27.100000       1.600000     114.000000                  27.400000
# 75%        31.300000       4.000000     147.000000                  37.400000
# max        46.700000      92.400000     323.000000                  55.000000
#
#        Public_Transport_Usage_Minutes  Electricity_Consumption_kWh  \
# count                   100000.000000                100000.000000
# mean                        30.764970                     9.884848
# ...

# %%
dc.dtypes
# Out:
# Record_ID                             str
# Date                                  str
# Day_Name                              str
# City                                  str
# Area_Type                             str
# Citizen_ID                            str
# Age_Group                             str
# Work_Mode                             str
# Temperature_C                     float64
# Rainfall_mm                       float64
# AQI                               float64
# Traffic_Level                         str
# Average_Traffic_Speed_kmh         float64
# Primary_Transport                     str
# Public_Transport_Usage_Minutes      int64
# Electricity_Consumption_kWh       float64
# Water_Consumption_Liters            int64
# Internet_Usage_GB                 float64
# Online_Food_Orders                  int64
# Daily_Spending_INR                float64
# Hospital_Visits                     int64
# Emergency_Complaints                int64
# ...

# %%
dc.isnull().sum()
# Out:
# Record_ID                         0
# Date                              0
# Day_Name                          0
# City                              0
# Area_Type                         0
# Citizen_ID                        0
# Age_Group                         0
# Work_Mode                         0
# Temperature_C                     0
# Rainfall_mm                       0
# AQI                               0
# Traffic_Level                     0
# Average_Traffic_Speed_kmh         0
# Primary_Transport                 0
# Public_Transport_Usage_Minutes    0
# Electricity_Consumption_kWh       0
# Water_Consumption_Liters          0
# Internet_Usage_GB                 0
# Online_Food_Orders                0
# Daily_Spending_INR                0
# Hospital_Visits                   0
# Emergency_Complaints              0
# Work_Hours                        0
# Outdoor_Activity_Hours            0
# Happiness_Score                   0
# Service_Satisfaction              0
# ...

# %%
dc["Date"] = pd.to_datetime(dc["Date"])

# %%
dc["Temperature_C"].head(5)
# Out:
# 0    31.4
# 1    21.2
# 2    20.6
# 3    21.8
# 4    29.3
# Name: Temperature_C, dtype: float64

# %% [markdown]
# ### NumPy Analysis

# %% [markdown]
# Q1. Create a NumPy array for Temperature_C and find the minimum, maximum, and mean temperature.

# %%
temp = dc["Temperature_C"].to_numpy()
# # Minimum temperature
min_temp = np.min(temp)

# # Maximum temperature
max_temp = np.max(temp)

# # Mean temperature
mean_temp = np.mean(temp).round(1)

print("Minimum Temperature:", min_temp)
print("Maximum Temperature:", max_temp)
print("Mean Temperature:", mean_temp)
# Out:
# Minimum Temperature: 6.8
# Maximum Temperature: 46.7
# Mean Temperature: 27.1

# %% [markdown]
# Q2. Calculate the mean, median, and standard deviation of AQI(Air Quality Index).

# %%
dc["AQI"].head(5)
# Out:
# 0     47.0
# 1    105.0
# 2     93.0
# 3     84.0
# 4    144.0
# Name: AQI, dtype: float64

# %%
AQI = dc["AQI"].to_numpy()

# Mean Air Quality Index
MEAN_AQI = np.mean(AQI).round(1)

# Median Air Quality Index
MEDIAN_AQI = np.median(AQI)

# Standard deviation Air Quality Index
STD_AQI = np.std(AQI).round(1)

print("Mean Air Quality Index:", MEAN_AQI)
print("Median Air Quality Index:", MEDIAN_AQI)
print("Standard deviation Air Quality Index:", STD_AQI)
# Out:
# Mean Air Quality Index: 115.7
# Median Air Quality Index: 114.0
# Standard deviation Air Quality Index: 47.4

# %% [markdown]
# Q3. Find the minimum and maximum daily spending from Daily_Spending_INR.

# %%
dc["Daily_Spending_INR"]
# Out:
# 0         322.38
# 1        1055.15
# 2          99.29
# 3         208.41
# 4        1088.10
#           ...
# 99995     984.99
# 99996    1284.73
# 99997    1368.49
# 99998     768.40
# 99999    1909.19
# Name: Daily_Spending_INR, Length: 100000, dtype: float64

# %%
DSI = dc["Daily_Spending_INR"].to_numpy()

# Minimum Daily Spending INR
Min_DSI = np.min(DSI)

# Maximum Daily Spending INR
Max_DSI = np.max(DSI)

print("Minimum Daily Spending INR:", Min_DSI)
print("Maximum Daily Spending INR:", Max_DSI)
# Out:
# Minimum Daily Spending INR: 50.0
# Maximum Daily Spending INR: 3653.13

# %% [markdown]
# Q4. Calculate the average working hours from Work_Hours.

# %%
dc["Work_Hours"]
# Out:
# 0        10.2
# 1         6.2
# 2         8.3
# 3         0.5
# 4         7.0
#          ...
# 99995     8.9
# 99996     6.1
# 99997     3.0
# 99998     7.8
# 99999     6.8
# Name: Work_Hours, Length: 100000, dtype: float64

# %%
work_hours = dc["Work_Hours"].to_numpy()

# Average working hours calculate karein
avg_work_hours = np.mean(work_hours).round(2)

print("Average Working Hours:", avg_work_hours)
# Out:
# Average Working Hours: 6.6

# %% [markdown]
# Q5. Find the mean and median happiness score from Happiness_Score.

# %%
dc["Happiness_Score"]
# Out:
# 0         8.7
# 1         8.7
# 2         8.8
# 3         5.3
# 4         8.9
#          ...
# 99995     7.8
# 99996     8.7
# 99997     9.2
# 99998    10.0
# 99999     7.9
# Name: Happiness_Score, Length: 100000, dtype: float64

# %%
Happy_score = dc["Happiness_Score"].to_numpy()

mean_Happiness_Score = np.mean(dc["Happiness_Score"]).round(2)

median_Happiness_Score = np.median(dc["Happiness_Score"]).round(2)

print("Mean Happiness Score", mean_Happiness_Score)
print("Median Happiness Score", median_Happiness_Score)
# Out:
# Mean Happiness Score 7.7
# Median Happiness Score 7.7

# %% [markdown]
# Q6. Count how many records have zero rainfall in Rainfall_mm.

# %% [markdown]
# Q7. Find the maximum AQI value and its position/index.

# %% [markdown]
# Q8. Count how many records have a temperature above 30°C.

# %% [markdown]
# Q9. Count how many citizens have daily spending above the average daily spending.

# %% [markdown]
# Q10. Calculate the 25th, 50th, and 75th percentiles of Work_Hours.

# %% [markdown]
# Q11. Calculate the variance and standard deviation of Electricity_Consumption_kWh.

# %% [markdown]
# Q12. Calculate the average internet usage from Internet_Usage_GB.

# %% [markdown]
# Q13. Find the maximum value of Outdoor_Activity_Hours.

# %% [markdown]
# Q14. Calculate the correlation between Water_Consumption_Liters and Electricity_Consumption_kWh.

# %% [markdown]
# Q15. Calculate the correlation coefficient between Temperature_C and AQI.

# %% [markdown]
# ### 🐼 Pandas EDA(Exploratory Data Analysis) Questions |||| 📊 Matplotlib Visualization:

# %% [markdown]
# Q1. Check the shape of the dataset (number of rows and columns).

# %%
dc.shape
# Out:
# (100000, 32)

# %% [markdown]
# Q2. Check the data type of each column.

# %%
dc.dtypes
# Out:
# Record_ID                                    str
# Date                              datetime64[us]
# Day_Name                                     str
# City                                         str
# Area_Type                                    str
# Citizen_ID                                   str
# Age_Group                                    str
# Work_Mode                                    str
# Temperature_C                            float64
# Rainfall_mm                              float64
# AQI                                      float64
# Traffic_Level                                str
# Average_Traffic_Speed_kmh                float64
# Primary_Transport                            str
# Public_Transport_Usage_Minutes             int64
# Electricity_Consumption_kWh              float64
# Water_Consumption_Liters                   int64
# Internet_Usage_GB                        float64
# Online_Food_Orders                         int64
# ...

# %% [markdown]
# Q3. Check whether the dataset contains any missing values.

# %%
dc.isnull().sum()
# Out:
# Record_ID                         0
# Date                              0
# Day_Name                          0
# City                              0
# Area_Type                         0
# Citizen_ID                        0
# Age_Group                         0
# Work_Mode                         0
# Temperature_C                     0
# Rainfall_mm                       0
# AQI                               0
# Traffic_Level                     0
# Average_Traffic_Speed_kmh         0
# Primary_Transport                 0
# Public_Transport_Usage_Minutes    0
# Electricity_Consumption_kWh       0
# Water_Consumption_Liters          0
# Internet_Usage_GB                 0
# Online_Food_Orders                0
# Daily_Spending_INR                0
# Hospital_Visits                   0
# Emergency_Complaints              0
# Work_Hours                        0
# Outdoor_Activity_Hours            0
# Happiness_Score                   0
# Service_Satisfaction              0
# ...

# %% [markdown]
# Q4. Check whether the dataset contains any duplicate rows.

# %%
dc.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Q5. Generate a statistical summary of all numerical columns using describe().

# %%
dc.describe()
# Out:
#                              Date  Temperature_C    Rainfall_mm  \
# count                      100000  100000.000000  100000.000000
# mean   2024-07-01 12:31:59.808000      27.122641       3.664261
# min           2023-01-01 00:00:00       6.800000       0.000000
# 25%           2023-10-01 00:00:00      23.000000       0.600000
# 50%           2024-07-01 00:00:00      27.100000       1.600000
# 75%           2025-04-02 00:00:00      31.300000       4.000000
# max           2025-12-31 00:00:00      46.700000      92.400000
# std                           NaN       5.535933       5.653815
#
#                  AQI  Average_Traffic_Speed_kmh  \
# count  100000.000000              100000.000000
# mean      115.652720                  27.924011
# min        20.000000                   4.000000
# 25%        82.000000                  16.200000
# 50%       114.000000                  27.400000
# 75%       147.000000                  37.400000
# ...

# %%
dc.columns
# Out:
# Index(['Record_ID', 'Date', 'Day_Name', 'City', 'Area_Type', 'Citizen_ID',
#        'Age_Group', 'Work_Mode', 'Temperature_C', 'Rainfall_mm', 'AQI',
#        'Traffic_Level', 'Average_Traffic_Speed_kmh', 'Primary_Transport',
#        'Public_Transport_Usage_Minutes', 'Electricity_Consumption_kWh',
#        'Water_Consumption_Liters', 'Internet_Usage_GB', 'Online_Food_Orders',
#        'Daily_Spending_INR', 'Hospital_Visits', 'Emergency_Complaints',
#        'Work_Hours', 'Outdoor_Activity_Hours', 'Happiness_Score',
#        'Service_Satisfaction', 'Weekend', 'Month', 'Year', 'Day', 'Month_Name',
#        'Quarter'],
#       dtype='str')

# %% [markdown]
# ## City Analysis

# %% [markdown]
# Q6. Find the total number of unique cities in the dataset.

# %%
dc["City"].unique()
# Out:
# <StringArray>
# [   'Mumbai', 'Hyderabad',    'Jaipur',     'Delhi',      'Pune',   'Kolkata',
#    'Chennai', 'Bengaluru']
# Length: 8, dtype: str

# %% [markdown]
# Q7. Count the number of records for each city.

# %%
dc["City"].value_counts()
# Out:
# City
# Chennai      12634
# Pune         12572
# Delhi        12534
# Mumbai       12531
# Jaipur       12490
# Bengaluru    12446
# Hyderabad    12421
# Kolkata      12372
# Name: count, dtype: int64

# %% [markdown]
# Q8. Calculate the average temperature for each city.

# %%
avg_temp = dc.groupby("City")["Temperature_C"].mean().round(2)
avg_temp
# Out:
# City
# Bengaluru    23.91
# Chennai      29.99
# Delhi        26.03
# Hyderabad    27.99
# Jaipur       26.96
# Kolkata      28.05
# Mumbai       29.04
# Pune         24.99
# Name: Temperature_C, dtype: float64

# %% [markdown]
# ### Q2. City-wise Average Temperature
# Create a Bar Chart to compare the average temperature across all cities.

# %%
avg_temp = avg_temp.sort_values(ascending=False)
plt.figure(figsize=(13, 7), facecolor="#121314")
bars = plt.bar(
    avg_temp.index,
    avg_temp.values,
    color=["green", "white", "blue", "brown", "Yellow", "red", "cyan", "pink"],
    edgecolor="black",
    linewidth=1.2
)

plt.title(
    "CITY WISE AVERAGE TEMPERATURE",
    color="white",
    fontsize=18,
    fontweight="bold",
    pad=20
)

plt.xlabel(
    "CITY",
    color="white",
    fontsize=13,
    fontweight="bold",
    labelpad=13
)

plt.ylabel(
    "TEMPERATURE",
    color="white",
    fontsize=13,
    fontweight="bold",
    labelpad=13 
)

plt.xticks(
    color="white",
    ha="center",
    rotation=0,
    fontweight="bold", 
)

plt.yticks(
    color="white",
    fontweight="bold", 
    fontsize=13
)

plt.grid(
    axis="y",
    linestyle="--",
    color="white",
    alpha=0.9,
)

for bar in bars:
    value = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 1,
        f"{value:,.2f}",
        ha="center",
        va="bottom",
        fontsize=13,
        fontweight="bold",
        color="white"
    )

plt.gca().set_facecolor("#121314")
plt.gca().spines["left"].set_color("cyan")
plt.gca().spines["bottom"].set_color("blue")
plt.gca().spines["top"].set_color("black")
plt.gca().spines["right"].set_color("black")

plt.tight_layout()

plt.show()

# %% [markdown]
# Q9. Calculate the average AQI for each city.

# %%
Avg_Aqi_City = dc.groupby("City")["AQI"].mean().round(2)
Avg_Aqi_City
# Out:
# City
# Bengaluru     80.27
# Chennai       99.58
# Delhi        173.58
# Hyderabad    104.31
# Jaipur       144.15
# Kolkata      138.48
# Mumbai       109.42
# Pune          75.72
# Name: AQI, dtype: float64

# %% [markdown]
# ### Q1. City-wise Average AQI
# - Create a Bar Chart to compare the average AQI across all cities.

# %%
Avg_Aqi_City = Avg_Aqi_City.sort_values(ascending=False)
plt.figure(figsize=(12, 6), facecolor="#121314")

bars = plt.bar(
    Avg_Aqi_City.index,
    Avg_Aqi_City.values,
    color=["green", "Yellow", "red", "cyan", "pink", "white", "blue", "brown"],
    edgecolor="black",
    linewidth=1.2
)

plt.title(
    "CITY WISE AIR QUALITY INDEX",
    color="white",
    fontsize=18,
    fontweight="bold",
    pad=20
)

plt.xlabel(
    "City",
    color="white",
    fontsize = 18,
    fontweight="bold",
    labelpad=13
)

plt.ylabel(
    "Average AQI",
    color="white",
    fontsize = 18,
    fontweight="bold",
    labelpad=13
)

plt.gca().set_facecolor("#121314")

plt.xticks(
    rotation=0,
    ha="center",
    fontsize=10,
    fontweight="bold",
    color="white"
)

plt.yticks(
    fontsize=10,
    fontweight="bold",
    color="white"
)

plt.grid(
    axis="y",
    linestyle="--",
    alpha=0.4,
    color="cyan"
)

for bar in bars:
    value = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 2,
        f"{value:,.2f}",
        ha="center",
        va="bottom",
        fontsize=13,
        fontweight="bold",
        color="white"
    )

plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_color("red")
plt.gca().spines["bottom"].set_color("yellow")

plt.grid(
    axis="y",
    linestyle="--",
    alpha=0.4,
    color="cyan"
)

plt.gca().xaxis.grid(False)

plt.tight_layout()

plt.show()

# %% [markdown]
# Q10. Calculate the average daily spending for each city.

# %%
Avg_Daily_Spending = dc.groupby("City")["Daily_Spending_INR"].mean().round(2)
Avg_Daily_Spending
# Out:
# City
# Bengaluru    1013.77
# Chennai      1010.97
# Delhi        1014.64
# Hyderabad    1015.99
# Jaipur       1016.32
# Kolkata      1027.37
# Mumbai       1017.95
# Pune         1015.92
# Name: Daily_Spending_INR, dtype: float64

# %% [markdown]
# ### Q3. City-wise Average Daily Spending
# - Create a Bar Chart to compare average daily spending across all cities.

# %%
plt.figure(figsize=(13, 7), facecolor="#121314")

bars = plt.bar(
    Avg_Daily_Spending.index,
    Avg_Daily_Spending.values,
    edgecolor = "black",
    color=["green", "Yellow", "red", "cyan", "pink", "white", "blue", "brown"],
    linewidth=1.2
)

plt.title(
    "CITY WISE AVERAGE DAILY SPENDING",
    color="white",
    fontsize=18,
    fontweight="bold",
    pad=20
)

plt.xlabel(
    "CITY",
    color="white",
    fontsize=13,
    fontweight="bold",
    labelpad=20
)

plt.ylabel(
    "DAILY SPENDING",
    color="white",
    fontsize=13,
    fontweight="bold",
    labelpad=20
)

plt.xticks(
    color="white",
    fontsize=13,
    fontweight="bold",
    ha="center",
    rotation=0 
)

plt.yticks(
    color="white",
    fontsize=13,
    fontweight="bold"
)

plt.grid(
    axis="y",
    linestyle="--",
    alpha=0.9,
    color="cyan"
)

for bar in bars:
    value = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 10, 
        f"{value:,.2f}",
        ha="center",
        va="bottom",
        color="white",
        fontsize=13,
        fontweight="bold",        
    )
    

plt.gca().set_facecolor("#121314")
plt.gca().spines["bottom"].set_color("pink")
plt.gca().spines["top"].set_color("black")
plt.gca().spines["right"].set_color("black")
plt.gca().spines["left"].set_color("red")

plt.tight_layout()

plt.show()

# %% [markdown]
# Q11. Which city has the highest average AQI?

# %%
avg_city_aqi = dc.groupby("City")["AQI"].mean().round(2)
highest_aqi_city = avg_city_aqi.idxmax()
print("City with Highest Average AQI:", highest_aqi_city)
print("Highest Average AQI:", avg_city_aqi.max())
# Out:
# City with Highest Average AQI: Delhi
# Highest Average AQI: 173.58

# %% [markdown]
# Q12. Which city has the lowest average AQI?

# %%
avg_city_aqi = dc.groupby("City")["AQI"].mean().round(2)
highest_aqi_city = avg_city_aqi.idxmin()
print("City with Lower Average AQI:", highest_aqi_city)
print("Lower Average AQI:", avg_city_aqi.min())
# Out:
# City with Lower Average AQI: Pune
# Lower Average AQI: 75.72

# %% [markdown]
# ## Weather Analysis

# %% [markdown]
# Q13. Calculate the average temperature for each month Name.

# %%
avg_month_temp = (
    dc.groupby(["Month", "Month_Name"])["Temperature_C"]
    .mean()
    .round(2)
    .reset_index()
    .sort_values("Month")
    .reset_index(drop=True)
)

avg_month_temp
# Out:
#     Month Month_Name  Temperature_C
# 0       1    January          21.92
# 1       2   February          24.14
# 2       3      March          27.06
# 3       4      April          30.14
# 4       5        May          32.32
# 5       6       June          33.19
# 6       7       July          32.33
# 7       8     August          30.11
# 8       9  September          27.14
# 9      10    October          24.09
# 10     11   November          21.96
# 11     12   December          21.14

# %%
avg_month_temp = (
    dc.groupby(["Month", "Month_Name"])["Temperature_C"]
    .mean()
    .round(2)
    .reset_index()
    .sort_values("Month")
)

avg_month_temp
# Out:
#     Month Month_Name  Temperature_C
# 0       1    January          21.92
# 1       2   February          24.14
# 2       3      March          27.06
# 3       4      April          30.14
# 4       5        May          32.32
# 5       6       June          33.19
# 6       7       July          32.33
# 7       8     August          30.11
# 8       9  September          27.14
# 9      10    October          24.09
# 10     11   November          21.96
# 11     12   December          21.14

# %% [markdown]
# Q14. Calculate the total rainfall for each month.

# %%
Total_rainfall_month =(
    dc.groupby(["Month", "Month_Name"])["Rainfall_mm"]
    .sum()
    .reset_index()
    .sort_values("Month")
)

Total_rainfall_month
# Out:
#     Month Month_Name  Rainfall_mm
# 0       1    January      12917.7
# 1       2   February      11640.6
# 2       3      March      12867.6
# 3       4      April      12387.5
# 4       5        May      12428.0
# 5       6       June      64932.0
# 6       7       July      67406.0
# 7       8     August      68152.9
# 8       9  September      65687.2
# 9      10    October      12706.4
# 10     11   November      12529.5
# 11     12   December      12770.7

# %% [markdown]
# Q15. Which month has the highest average temperature?

# %%
avg_month_temp = (
    dc.groupby("Month_Name")["Temperature_C"]
    .mean()
    .round(2)
)

highest_month = avg_month_temp.idxmax()

print("Month Name with Highest Average Temperature:", highest_month)
print("Highest Average Temperature:", avg_month_temp.max())
# Out:
# Month Name with Highest Average Temperature: June
# Highest Average Temperature: 33.19

# %% [markdown]
# Q16. Which month has the highest total rainfall?

# %%
highest_month_rainfall = (
    dc.groupby("Month_Name")["Rainfall_mm"]
    .sum()
    .round(2)
)

highest_total_rainfall = highest_month_rainfall.idxmax()

print("Month Name with Highest Total Rainfall:", highest_total_rainfall)
print("Highest Rainfall:", highest_month_rainfall.max())
# Out:
# Month Name with Highest Total Rainfall: August
# Highest Rainfall: 68152.9

# %% [markdown]
# ## Traffic Analysis

# %% [markdown]
# Q17. Calculate the count of each category in Traffic_Level.

# %%
dc["Traffic_Level"].str.strip()
# Out:
# 0           Low
# 1        Medium
# 2           Low
# 3           Low
# 4           Low
#           ...
# 99995       Low
# 99996    Medium
# 99997    Medium
# 99998    Medium
# 99999    Severe
# Name: Traffic_Level, Length: 100000, dtype: str

# %%
dc["Traffic_Level"].value_counts()
# Out:
# Traffic_Level
# Medium    35185
# Low       26834
# High      22173
# Severe    15808
# Name: count, dtype: int64

# %% [markdown]
# Q18. Calculate the average traffic speed for each traffic level.

# %%
avg_speed = (
    dc.groupby("Traffic_Level")["Average_Traffic_Speed_kmh"].mean().round(2)
)
avg_speed
# Out:
# Traffic_Level
# High      17.48
# Low       44.99
# Medium    30.00
# Severe     8.99
# Name: Average_Traffic_Speed_kmh, dtype: float64

# %% [markdown]
# ## Q5. Traffic Level vs Average Speed
# - Create a Bar Chart to compare average traffic speed for Low, Medium, and High traffic levels.

# %% [markdown]
# Q19. Which traffic level has the lowest average traffic speed?

# %%
low_avg_speed = (
    dc.groupby("Traffic_Level")["Average_Traffic_Speed_kmh"].mean().round(2)
)
avg_speed

low_avg_traffic_speed = low_avg_speed.idxmin()

print("Traffic the Lower avg Traffic Speed:", low_avg_traffic_speed)
print("Lower avg Traffic Speed:", low_avg_speed.min())
# Out:
# Traffic the Lower avg Traffic Speed: Severe
# Lower avg Traffic Speed: 8.99

# %% [markdown]
# Q20. Calculate the average traffic speed for each city.

# %%
avg_traffic_speed = dc.groupby("City")["Average_Traffic_Speed_kmh"].mean().round(2)
avg_traffic_speed
# Out:
# City
# Bengaluru    27.69
# Chennai      28.28
# Delhi        24.12
# Hyderabad    28.98
# Jaipur       32.52
# Kolkata      26.76
# Mumbai       24.85
# Pune         30.21
# Name: Average_Traffic_Speed_kmh, dtype: float64

# %% [markdown]
# ## Q4. City-wise Average Traffic Speed
# - Create a Bar Chart to compare the average traffic speed across all cities.

# %%
plt.figure(figsize=(13,7), facecolor="#121212")
bars = plt.bar(
    avg_traffic_speed.index,
    avg_traffic_speed.values,
    color=["green", "Yellow", "red", "cyan", "pink", "white", "blue", "brown"],
    # edgecolor="white",
    linewidth=1.2
)

plt.title(
    "CITY WISE AVERAGE TRAFFIC SPEED",
    pad=20,
    color="white",
    fontweight="bold",
    fontsize=18
)

plt.xlabel(
    "CITY",
    color="white",
    labelpad = 13,
    fontsize=15,
    fontweight="bold"
)

plt.ylabel(
    "AVERAGE TRAFFIC SPEED",
    color="white",
    labelpad = 13,
    fontsize=15,
    fontweight="bold"
)

plt.xticks(
    color="white",
    fontsize=10,
    ha="center",
    fontweight="bold"
)

plt.yticks(
    color="white",
    fontsize=10,
    fontweight="bold"
)

plt.grid(
    axis="y",
    linestyle="--",
    color="cyan",
    alpha=0.9
)

for bar in bars:
    value = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value,
        f"{value:,.2f}",
        ha="center",
        va="bottom",
        fontsize=13,
        fontweight="bold",
        color="white"
    )

plt.gca().set_facecolor("#1e1e1e")
plt.gca().spines["top"].set_color("black")
plt.gca().spines["right"].set_color("black")
plt.gca().spines["left"].set_color("white")
plt.gca().spines["bottom"].set_color("white")

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Spending Analysis

# %% [markdown]
# Q21. Calculate the total daily spending for each city.

# %%
total_daily_spending = dc.groupby("City")["Daily_Spending_INR"].sum().round(2)
total_daily_spending
# Out:
# City
# Bengaluru    12617427.51
# Chennai      12772551.38
# Delhi        12717506.09
# Hyderabad    12619597.54
# Jaipur       12693833.60
# Kolkata      12710680.90
# Mumbai       12755909.03
# Pune         12772206.26
# Name: Daily_Spending_INR, dtype: float64

# %% [markdown]
# Q22. Calculate the average daily spending for each age group.

# %%
avg_daily_spending = ( 
    dc.groupby("Age_Group")["Daily_Spending_INR"].mean().round(2)
)
avg_daily_spending
# Out:
# Age_Group
# 18-24    1014.75
# 25-34    1018.65
# 35-44    1016.49
# 45-54    1014.94
# 55+      1016.13
# Name: Daily_Spending_INR, dtype: float64

# %% [markdown]
# ## Q6. Age Group-wise Average Spending
# Create a Bar Chart to compare average daily spending across different age groups.

# %%
plt.figure(figsize=(13, 6), facecolor="white")

bars = plt.bar(
    avg_daily_spending.index,
    avg_daily_spending.values
)

# %% [markdown]
# Q23. Calculate the average daily spending for each work mode.

# %% [markdown]
# Q24. Compare the average daily spending on weekends and weekdays.

# %% [markdown]
# ## Work and Lifestyle Analysis

# %% [markdown]
# Matpltlib
# #### Q8. Age Group vs Happiness Score
# Create a Bar Chart to compare the average happiness score across different age groups.
# #### Q9. Primary Transport Usage
# Create a Bar Chart showing the number of people using each primary mode of transportation.
# #### Q9. Primary Transport Usage
# Create a Bar Chart showing the number of people using each primary mode of transportation.

# %% [markdown]
# Q25. Calculate the average work hours for each work mode.

# %% [markdown]
# ## Q7. Work Mode vs Average Work Hours
# - Create a Bar Chart to compare average work hours across different work modes.

# %% [markdown]
# Q26. Calculate the average happiness score for each age group.

# %% [markdown]
# Q27. Analyze the relationship between work hours and happiness score.

# %% [markdown]
# Q28. Analyze the relationship between outdoor activity hours and happiness score.

# %% [markdown]
# ## Transport Analysis

# %% [markdown]
# Q29. Calculate the usage count of each category in Primary_Transport.

# %% [markdown]
# Q30. Calculate the average public transport usage minutes for each primary transport type.

# %% [markdown]
# ## Area Type Analysis

# %% [markdown]
# Q31. Calculate the number of records for each Area_Type.

# %% [markdown]
# Q32. Calculate the average daily spending for each Area_Type.

# %% [markdown]
# Q33. Calculate the average happiness score for each Area_Type.

# %% [markdown]
# Q34. Calculate the average AQI for each Area_Type.

# %% [markdown]
# Q35. Calculate the average electricity consumption for each Area_Type.

# %% [markdown]
# ## Q10. Area Type vs Electricity Consumption
# - Create a Bar Chart to compare average electricity consumption across different area types.

# %% [markdown]
# ## Electricity and Water Consumption Analysis

# %% [markdown]
# Q36. Calculate the average electricity consumption for each city.

# %% [markdown]
# Q37. Calculate the average water consumption for each city.

# %% [markdown]
# Q38. Which city has the highest average electricity consumption?

# %% [markdown]
# Q39. Which city has the highest average water consumption?

# %% [markdown]
# Q40. Calculate the average electricity consumption for each Area_Type.

# %% [markdown]
# Q41. Calculate the average water consumption for each Area_Type.

# %% [markdown]
# ## Internet Usage Analysis

# %% [markdown]
# Q42. Calculate the average internet usage for each age group.

# %% [markdown]
# Q43. Calculate the average internet usage for each work mode.

# %% [markdown]
# Q44. Which age group has the highest average internet usage?

# %% [markdown]
# Q45. Analyze the relationship between Internet_Usage_GB and Daily_Spending_INR.

# %% [markdown]
# ### Online Food Order Analysis

# %% [markdown]
# Q46. Calculate the average number of online food orders for each age group.

# %% [markdown]
# Q47. Calculate the average number of online food orders for each work mode.

# %% [markdown]
# Q48. Analyze the relationship between Online_Food_Orders and Daily_Spending_INR.

# %% [markdown]
# Q49. Which city has the highest average number of online food orders.

# %% [markdown]
# ### Healthcare Analysis

# %% [markdown]
# Q50. Calculate the total number of hospital visits for each city.

# %% [markdown]
# Q51. Calculate the average number of hospital visits for each age group.

# %% [markdown]
# Q52. Calculate the total number of emergency complaints for each city.

# %% [markdown]
# Q53. Which city has the highest number of emergency complaints?

# %% [markdown]
# Q54. Analyze the relationship between AQI and Hospital_Visits.

# %% [markdown]
# ### Service Satisfaction Analysis

# %% [markdown]
# Q55. Calculate the average service satisfaction score for each city.

# %% [markdown]
# Q56. Calculate the average service satisfaction score for each Area_Type.

# %% [markdown]
# Q57. Analyze the relationship between Service_Satisfaction and Happiness_Score.

# %% [markdown]
# Q58. Which city has the highest average service satisfaction?

# %% [markdown]
# ### Time-Based Analysis

# %% [markdown]
# Q59. Calculate the average AQI for each month.

# %% [markdown]
# Q60. Calculate the average daily spending for each month.

# %% [markdown]
# Q61. Calculate the average happiness score for each month.

# %% [markdown]
# Q62. Calculate the average AQI for each quarter.

# %% [markdown]
# Q63. Calculate the average daily spending for each quarter.

# %% [markdown]
# Q64. Calculate the average temperature for each quarter.

# %% [markdown]
# 📈 B. Line Chart — 5 Questions
# Q11. Month-wise Average Temperature
# Create a Line Chart to show the average temperature trend across months.
#
# Q12. Month-wise Total Rainfall
#
# Create a Line Chart to show the total rainfall trend across months.
#
# Q13. Month-wise Average AQI
#
# Create a Line Chart to show how the average AQI changes across months.
#
# Q14. Month-wise Average Daily Spending
#
# Create a Line Chart to show the monthly trend of average daily spending.
#
# Q15. Month-wise Average Happiness Score
#
# Create a Line Chart to show the monthly trend of average happiness scores.
#
# 🥧 C. Pie Chart — 3 Questions
# Q16. Traffic Level Distribution
#
# Create a Pie Chart showing the percentage distribution of Low, Medium, and High traffic levels.
#
# Q17. Work Mode Distribution
#
# Create a Pie Chart showing the percentage distribution of different work modes.
#
# Q18. Area Type Distribution
#
# Create a Pie Chart showing the percentage distribution of different area types.
#
# 📍 D. Scatter Plot — 5 Questions
# Q19. Work Hours vs Happiness Score
#
# Create a Scatter Plot to analyze the relationship between work hours and happiness score.
#
# Q20. Outdoor Activity vs Happiness Score
#
# Create a Scatter Plot to analyze the relationship between outdoor activity hours and happiness score.
#
# Q21. Temperature vs AQI
#
# Create a Scatter Plot to analyze the relationship between temperature and AQI.
#
# Q22. Internet Usage vs Daily Spending
#
# Create a Scatter Plot to analyze the relationship between internet usage and daily spending.
#
# Q23. Service Satisfaction vs Happiness Score
#
# Create a Scatter Plot to analyze whether service satisfaction is related to happiness score.
#
# 📦 E. Histogram — 1 Question
# Q24. Daily Spending Distribution
#
# Create a Histogram to show the distribution of Daily_Spending_INR.
#
# Analyze:
#
# Most common spending range
# Distribution shape
# Spread of spending
# Possible skewness
# 📦 F. Box Plot — 1 Question
# Q25. Daily Spending by Age Group
#
# Create a Box Plot to compare Daily_Spending_INR across different age groups.
#
# Analyze:
#
# Median
# Q1 and Q3
# Interquartile Range (IQR)
# Minimum and maximum
# Outliers
