# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":['suraj', 'rahan', 'mohan', 'shubh'],
    "marks":[92, 34, 37, 87],
    "city":['rampur', 'kolkata', 'bareilly', 'antarctica']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks        city
# 0  suraj     92      rampur
# 1  rahan     34     kolkata
# 2  mohan     37    bareilly
# 3  shubh     87  antarctica

# %%
df.to_csv("suraj.csv")
