# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Anish Kumar\OneDrive\Documents\GitHub\PANDAS-CURSE\DOC\archive\Airbnb_Open_Data.csv")
# Out:
# C:\Users\Anish Kumar\AppData\Local\Temp\ipykernel_11440\3203244283.py:1: DtypeWarning: Columns (0: license) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Anish Kumar\OneDrive\Documents\GitHub\PANDAS-CURSE\DOC\archive\Airbnb_Open_Data.csv")

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df.tail()
# Out:
#              id                              NAME      host id  \
# 102594  6092437        Spare room in Williamsburg  12312296767
# 102595  6092990     Best Location near Columbia U  77864383453
# 102596  6093542    Comfy, bright room in Brooklyn  69050334417
# 102597  6094094  Big Studio-One Stop from Midtown  11160591270
# 102598  6094647              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# 102594               verified         Krik            Brooklyn
# 102595            unconfirmed        Mifan           Manhattan
# 102596            unconfirmed        Megan            Brooklyn
# 102597            unconfirmed  Christopher              Queens
# 102598            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  str
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  str
#  4   host name                       102193 non-null  str
#  5   neighbourhood group             102570 non-null  str
#  6   neighbourhood                   102583 non-null  str
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  str
#  10  country code                    102468 non-null  str
#  11  instant_bookable                102494 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='str')

# %% [markdown]
# ### Solve the Query
# - Deleting redundant columns.
# - Renaming the columns.
# - Dropping the columns.
# - Cleaning individual columns
# - Remove the NaN values form the dataset
# - Check for some more Transformations

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']

columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license','id']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 7

# %% [markdown]
# ## 1st Method, Filtering Data

# %%
data = df[columns_to_keep]

# %%
data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %% [markdown]
# ## 2nd method, Dropping Columns

# %%
df.drop(columns = columns_to_drop, inplace=True)

# %%
df.shape
# Out:
# (102599, 19)

# %%
"""
Base Exception Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Cleaning individual columns.
Remove the NaN values from the dataset.
Check for some more transformations."""
# Out:
# '\nBase Exception Deleting redundant columns.\nRenaming the columns.\nDropping duplicates.\nCleaning individual columns.\nRemove the NaN values from the dataset.\nCheck for some more transformations.'

# %%
data
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
data.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='str')

# %%
data.rename(columns = {"NAME":"Name"}, inplace=True)

# %%
data.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='str')

# %%
new_columns_names = []
for i in df.columns:
    new_columns_names.append(i.upper())

# %%
type(new_columns_names)
# Out:
# list

# %%
new_datafram_to_modify = data.copy()

# %%
new_datafram_to_modify.columns = new_columns_names

# %%
new_datafram_to_modify.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='str')

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
"""Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Cleaning individual columns.
Remove the NaN values from the dataset.
Check for some more transformations"""
# Out:
# 'Deleting redundant columns.\nRenaming the columns.\nDropping duplicates.\nCleaning individual columns.\nRemove the NaN values from the dataset.\nCheck for some more transformations'

# %%
df.duplicated().sum()
# Out:
# np.int64(541)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# NAME                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
df.drop(columns=["last review"], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# NAME                      250
# host id                     0
# host_identity_verified    289
# host name                 404
# neighbourhood group        29
# neighbourhood              16
# lat                         8
# long                        8
# country                   532
# country code              131
# instant_bookable          105
# cancellation_policy        76
# room type                   0
# Construction year         214
# price                     247
# service fee               273
# minimum nights            400
# number of reviews         183
# dtype: int64

# %%
df["host_identity_verified"].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 2                 NaN
# 3         UNCONFIRMED
# 4            VERIFIED
#              ...
# 102053    UNCONFIRMED
# 102054       VERIFIED
# 102055       VERIFIED
# 102056    UNCONFIRMED
# 102057       VERIFIED
# Name: host_identity_verified, Length: 102058, dtype: str

# %%
df["host_identity_verified"] = df["host_identity_verified"].str.upper()

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102053               Cozy bright room near Prospect Park  77326652202
# 102054         Private Bedroom with Amazing Rooftop View  45936254757
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people  23801060917
# 102056        Room & private bathroom in historic Harlem  15593031571
# 102057                                   Rosalee Stewart  93578954226
#
#        host_identity_verified host name neighbourhood group  \
# 0                 UNCONFIRMED  Madaline            Brooklyn
# ...

# %%
df["instant_bookable"].apply(lambda x: 1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         0
#          ..
# 102053    1
# 102054    0
# 102055    1
# 102056    1
# 102057    0
# Name: instant_bookable, Length: 102058, dtype: int64

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#         index                                              NAME      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 99337  102029            Cozy room in a 2B with backyard access   5155155913
# 99338  102030                      An East Williamsburg Delight  71564706996
# 99339  102031                      Cozy bedroom in williamsburg  83101851929
# 99340  102032                            Spacious Room w/ 2 Bed  69037598918
# 99341  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
type(df["instant_bookable"][15])
# Out:
# bool

# %%
df["price"].head(5)
# Out:
# 0    $966
# 1    $142
# 2    $620
# 3    $368
# 4    $204
# Name: price, dtype: str

# %%
df["price"] = df["price"].str.replace("$","")

# %%
df["price"]
# Out:
# 0          966
# 1          142
# 2          620
# 3          368
# 4          204
#           ...
# 102053     696
# 102054     909
# 102055     387
# 102056     848
# 102057    1128
# Name: price, Length: 102058, dtype: str

# %%
df["price"] = df["price"].str.replace(",","")

# %%
df["price"][15]
# Out:
# '578'

# %%
df["price"] = df["price"].str.replace(" ","")

# %%
type(df["price"][1])
# Out:
# str

# %%
df["price"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df["price"].astype(int)
#
# File c:\Users\Anish Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File c:\Users\Anish Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
# ...

# %%
df["price"] = df["price"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df["price"] = df["price"].astype(int)
#
# File c:\Users\Anish Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File c:\Users\Anish Kumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
# ...

# %%
type(df["price"][1])
# Out:
# numpy.int64

# %%
data.to_csv("Cleaned_Data.csv")

# %%
pd.read_csv("Cleaned_Data.csv")
# Out:
#         Unnamed: 0                                              Name  \
# 0                0                Clean & quiet apt home by the park
# 1                1                             Skylit Midtown Castle
# 2                2               THE VILLAGE OF HARLEM....NEW YORK !
# 3                3                                               NaN
# 4                4  Entire Apt: Spacious Studio/Loft by central park
# ...            ...                                               ...
# 102594      102594                        Spare room in Williamsburg
# 102595      102595                     Best Location near Columbia U
# 102596      102596                    Comfy, bright room in Brooklyn
# 102597      102597                  Big Studio-One Stop from Midtown
# 102598      102598                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# ...
