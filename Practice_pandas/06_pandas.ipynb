# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Anish Kumar\Downloads\Pandas_Data_S.xlsx")

# %%
df
# Out:
#      OrderID                    Date      Customer       City     Product  \
# 0    ORD1001 2024-01-01 00:00:00.000   Ankit Verma       Pune      Webcam
# 1    ORD1002 2024-01-02 11:06:36.794   Pooja Kumar  Hyderabad     Monitor
# 2    ORD1003 2024-01-03 22:13:13.587   Ravi Sharma    Kolkata       Mouse
# 3    ORD1004 2024-01-05 09:19:50.381   Sneha Verma      Noida     Printer
# 4    ORD1005 2024-01-06 00:00:00.000   Sneha Gupta  Hyderabad  Headphones
# ..       ...                     ...           ...        ...         ...
# 495  ORD1496 2025-12-25 03:33:32.826   Priya Verma     Mumbai      Tablet
# 496  ORD1497 2025-12-26 14:40:09.619   Ankit Singh  Bengaluru  Headphones
# 497  ORD1498 2025-12-28 01:46:46.413   Vikas Gupta      Noida  Headphones
# 498  ORD1499 2025-12-29 12:53:23.206  Priya Sharma       Pune      Laptop
# 499  ORD1500 2025-12-31 00:00:00.000  Rahul Sharma    Gurgaon     Monitor
#
#         Category  Qty  UnitPrice   Sales                      Email  \
# ...

# %%
df.head(5)
# Out:
#    OrderID                    Date     Customer       City     Product  \
# 0  ORD1001 2024-01-01 00:00:00.000  Ankit Verma       Pune      Webcam
# 1  ORD1002 2024-01-02 11:06:36.794  Pooja Kumar  Hyderabad     Monitor
# 2  ORD1003 2024-01-03 22:13:13.587  Ravi Sharma    Kolkata       Mouse
# 3  ORD1004 2024-01-05 09:19:50.381  Sneha Verma      Noida     Printer
# 4  ORD1005 2024-01-06 00:00:00.000  Sneha Gupta  Hyderabad  Headphones
#
#       Category  Qty  UnitPrice   Sales                  Email       Phone  \
# 0  Accessories    8       2499   19992  ankit.verma@gmail.com  9692674377
# 1  Electronics    5        499    2495  pooja.kumar@gmail.com  9958092638
# 2  Accessories    4      49999  199996  ravi.sharma@gmail.com  9198941367
# 3  Electronics    6       4999   29994  sneha.verma@gmail.com  9935191937
# 4  Accessories    2       2499    4998  sneha.gupta@gmail.com  9798808687
#
#   Salesperson    Channel PaymentStatus Region
# 0       Rahul     ONLine       Pending   West
# ...

# %%
df.tail(5)
# Out:
#      OrderID                    Date      Customer       City     Product  \
# 495  ORD1496 2025-12-25 03:33:32.826   Priya Verma     Mumbai      Tablet
# 496  ORD1497 2025-12-26 14:40:09.619   Ankit Singh  Bengaluru  Headphones
# 497  ORD1498 2025-12-28 01:46:46.413   Vikas Gupta      Noida  Headphones
# 498  ORD1499 2025-12-29 12:53:23.206  Priya Sharma       Pune      Laptop
# 499  ORD1500 2025-12-31 00:00:00.000  Rahul Sharma    Gurgaon     Monitor
#
#         Category  Qty  UnitPrice   Sales                      Email  \
# 495  Electronics    4      49999  199996      priya.verma@gmail.com
# 496  Accessories    1       4999    4999      ankit.singh@gmail.com
# 497  Accessories    8        799    6392      vikas.gupta@gmail.com
# 498  Electronics   10       4999   49990     priya.sharma@gmail.com
# 499  Electronics    6       2499   14994    rahul.sharma@gmail.com
#
#           Phone Salesperson    Channel PaymentStatus Region
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"]).dt.strftime("%d/%m/%Y")

# %%
df
# Out:
#      OrderID        Date      Customer       City     Product     Category  \
# 0    ORD1001  01/01/2024   Ankit Verma       Pune      Webcam  Accessories
# 1    ORD1002  02/01/2024   Pooja Kumar  Hyderabad     Monitor  Electronics
# 2    ORD1003  03/01/2024   Ravi Sharma    Kolkata       Mouse  Accessories
# 3    ORD1004  05/01/2024   Sneha Verma      Noida     Printer  Electronics
# 4    ORD1005  06/01/2024   Sneha Gupta  Hyderabad  Headphones  Accessories
# ..       ...         ...           ...        ...         ...          ...
# 495  ORD1496  25/12/2025   Priya Verma     Mumbai      Tablet  Electronics
# 496  ORD1497  26/12/2025   Ankit Singh  Bengaluru  Headphones  Accessories
# 497  ORD1498  28/12/2025   Vikas Gupta      Noida  Headphones  Accessories
# 498  ORD1499  29/12/2025  Priya Sharma       Pune      Laptop  Electronics
# 499  ORD1500  31/12/2025  Rahul Sharma    Gurgaon     Monitor  Electronics
#
# ...

# %%
df.isna().sum()
# Out:
# OrderID          0
# Date             0
# Customer         0
# City             0
# Product          0
# Category         0
# Qty              0
# UnitPrice        0
# Sales            0
# Email            0
# Phone            0
# Salesperson      0
# Channel          0
# PaymentStatus    0
# Region           0
# dtype: int64

# %% [markdown]
# --> Remove all extra space from all string column

# %%
for col in df.select_dtypes(include="str"):
    df[col] = df[col].str.strip()

# %%
for col in df.select_dtypes(include="str"):
    df[col] = df[col].str.title()

# %%
df["Email"] = df["Email"].str.lower()

# %%
# String columns
for col in df.select_dtypes(include="str"):
    df[col] = df[col].fillna("N/A")

# Integer columns
for col in df.select_dtypes(include="number"):
    df[col] = df[col].fillna(0)

# %%
df.head(5)
# Out:
#    OrderID        Date     Customer       City     Product     Category  Qty  \
# 0  Ord1001  01/01/2024  Ankit Verma       Pune      Webcam  Accessories    8
# 1  Ord1002  02/01/2024  Pooja Kumar  Hyderabad     Monitor  Electronics    5
# 2  Ord1003  03/01/2024  Ravi Sharma    Kolkata       Mouse  Accessories    4
# 3  Ord1004  05/01/2024  Sneha Verma      Noida     Printer  Electronics    6
# 4  Ord1005  06/01/2024  Sneha Gupta  Hyderabad  Headphones  Accessories    2
#
#    UnitPrice   Sales                  Email       Phone Salesperson  Channel  \
# 0       2499   19992  Ankit.Verma@Gmail.Com  9692674377       Rahul   Online
# 1        499    2495  Pooja.Kumar@Gmail.Com  9958092638       Rahul   Online
# 2      49999  199996  Ravi.Sharma@Gmail.Com  9198941367       Rahul   Online
# 3       4999   29994  Sneha.Verma@Gmail.Com  9935191937       Karan  Offline
# 4       2499    4998  Sneha.Gupta@Gmail.Com  9798808687        Amit  Offline
#
#   PaymentStatus Region
# ...

# %% [markdown]
# Total duplicate rows kitni hain

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Duplicate rows ko dekhna ho

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [OrderID, Date, Customer, City, Product, Category, Qty, UnitPrice, Sales, Email, Phone, Salesperson, Channel, PaymentStatus, Region]
# Index: []

# %% [markdown]
# Duplicate rows remove karna ho

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#               Qty     UnitPrice          Sales
# count    8.000000      8.000000       8.000000
# mean    66.899843  11526.160342   92986.890021
# std    175.022830  16656.687930  168863.781204
# min      1.000000    499.000000     499.000000
# 25%      2.966686    874.250000    3720.500000
# 50%      5.166000   6249.000000   35243.500000
# 75%      8.500000  12569.070685   72602.214043
# max    500.000000  49999.000000  499990.000000
