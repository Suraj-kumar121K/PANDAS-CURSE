# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"c:\Pandas practice Data\01_Data.xlsx")
df
# Out:
#     Emp_ID   Name      Age Department   Salary Joining_Date     City  \
# 0       31   Neha  Unknown    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi       29         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya       40         HR      NaN   18-09-2022     Pune
# 3       36  Sneha       34      Sales      NaN   15-11-2020    Delhi
# 4       24  Karan       27         IT  31899.0   28-07-2022  Kolkata
# ..     ...    ...      ...        ...      ...          ...      ...
# 95      27   Ravi       28         HR      NaN   11-01-2021  Chennai
# 96      10  Sneha  Unknown      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  Unknown      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  Unknown    Finance      NaN   02-04-2022   Mumbai
# 99      27  Pooja  Unknown    Finance      NaN   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# ...

# %% [markdown]
# # Basic Data Inspection

# %%
df.head()
# Out:
#    Emp_ID   Name      Age Department   Salary Joining_Date     City  \
# 0      31   Neha  Unknown    Finance  50653.0   18-12-2020    Delhi
# 1      47   Ravi       29         HR  69988.0   18-10-2020   Mumbai
# 2      29  Priya       40         HR      NaN   18-09-2022     Pune
# 3      36  Sneha       34      Sales      NaN   15-11-2020    Delhi
# 4      24  Karan       27         IT  31899.0   28-07-2022  Kolkata
#
#    Performance_Score
# 0                  4
# 1                  2
# 2                  1
# 3                  4
# 4                  1

# %%
df.tail()
# Out:
#     Emp_ID   Name      Age Department   Salary Joining_Date     City  \
# 95      27   Ravi       28         HR      NaN   11-01-2021  Chennai
# 96      10  Sneha  Unknown      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  Unknown      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  Unknown    Finance      NaN   02-04-2022   Mumbai
# 99      27  Pooja  Unknown    Finance      NaN   23-08-2022  Chennai
#
#     Performance_Score
# 95                  4
# 96                  1
# 97                  5
# 98                  4
# 99                  2

# %%
df.shape
# Out:
# (100, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Emp_ID             100 non-null    int64
#  1   Name               100 non-null    object
#  2   Age                100 non-null    object
#  3   Department         100 non-null    object
#  4   Salary             53 non-null     float64
#  5   Joining_Date       100 non-null    object
#  6   City               100 non-null    object
#  7   Performance_Score  100 non-null    int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
df.describe()
# Out:
#            Emp_ID        Salary  Performance_Score
# count  100.000000     53.000000         100.000000
# mean    24.310000  56121.264151           3.000000
# std     14.765299  15065.095846           1.497473
# min      1.000000  31899.000000           1.000000
# 25%     10.000000  40528.000000           1.750000
# 50%     25.000000  57969.000000           3.000000
# 75%     36.000000  69668.000000           4.000000
# max     50.000000  79253.000000           5.000000

# %%
df.columns
# Out:
# Index(['Emp_ID', 'Name', 'Age', 'Department', 'Salary', 'Joining_Date', 'City',
#        'Performance_Score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Emp_ID                 int64
# Name                  object
# Age                   object
# Department            object
# Salary               float64
# Joining_Date          object
# City                  object
# Performance_Score      int64
# dtype: object

# %% [markdown]
# # Duplicate

# %%
df.isnull().sum()
# Out:
# Emp_ID                0
# Name                  0
# Age                   0
# Department            0
# Salary               47
# Joining_Date          0
# City                  0
# Performance_Score     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Convert INT

# %%
df["Salary"] = df["Salary"].round().astype("Int64")
df
# Out:
#     Emp_ID   Name      Age Department  Salary Joining_Date     City  \
# 0       31   Neha  Unknown    Finance   50653   18-12-2020    Delhi
# 1       47   Ravi       29         HR   69988   18-10-2020   Mumbai
# 2       29  Priya       40         HR    <NA>   18-09-2022     Pune
# 3       36  Sneha       34      Sales    <NA>   15-11-2020    Delhi
# 4       24  Karan       27         IT   31899   28-07-2022  Kolkata
# ..     ...    ...      ...        ...     ...          ...      ...
# 95      27   Ravi       28         HR    <NA>   11-01-2021  Chennai
# 96      10  Sneha  Unknown      Sales   72570   17-01-2021  Kolkata
# 97      30  Karan  Unknown      Sales   46938   18-12-2020  Kolkata
# 98      12  Rahul  Unknown    Finance    <NA>   02-04-2022   Mumbai
# 99      27  Pooja  Unknown    Finance    <NA>   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ...

# %% [markdown]
# # Fill Missing Value

# %%
df["Salary"] = df["Salary"].apply(
    lambda x: np.random.randint(31899, 79253) if pd.isna(x) else x
)
df
# Out:
#     Emp_ID   Name      Age Department   Salary Joining_Date     City  \
# 0       31   Neha  Unknown    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi       29         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya       40         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha       34      Sales  72905.0   15-11-2020    Delhi
# 4       24  Karan       27         IT  31899.0   28-07-2022  Kolkata
# ..     ...    ...      ...        ...      ...          ...      ...
# 95      27   Ravi       28         HR  49939.0   11-01-2021  Chennai
# 96      10  Sneha  Unknown      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  Unknown      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  Unknown    Finance  58011.0   02-04-2022   Mumbai
# 99      27  Pooja  Unknown    Finance  75038.0   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# ...

# %% [markdown]
# # Age Fill Missing value
# - "unknown" ko NaN me convert karo

# %%
df["Age"] = df["Age"].replace("Unknown", np.nan)
df
# Out:
# C:\Users\Anish Kumar\AppData\Local\Temp\ipykernel_28596\301595900.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Age"] = df["Age"].replace("Unknown", np.nan)
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha   NaN    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# ..     ...    ...   ...        ...      ...          ...      ...
# 95      27   Ravi  28.0         HR  49939.0   11-01-2021  Chennai
# ...

# %% [markdown]
# # Age ko numeric type me convert karo

# %%
df["Age"] = pd.to_numeric(df["Age"])
df
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha   NaN    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# ..     ...    ...   ...        ...      ...          ...      ...
# 95      27   Ravi  28.0         HR  49939.0   11-01-2021  Chennai
# 96      10  Sneha   NaN      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan   NaN      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul   NaN    Finance  58011.0   02-04-2022   Mumbai
# 99      27  Pooja   NaN    Finance  75038.0   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# ...

# %% [markdown]
# # Fill Missing Value

# %%
df["Age"] = df["Age"].apply(
    lambda x: np.random.randint(21, 40) if pd.isna(x) else x
)
df
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# ..     ...    ...   ...        ...      ...          ...      ...
# 95      27   Ravi  28.0         HR  49939.0   11-01-2021  Chennai
# 96      10  Sneha  31.0      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  36.0      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  27.0    Finance  58011.0   02-04-2022   Mumbai
# 99      27  Pooja  34.0    Finance  75038.0   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# ...

# %% [markdown]
# # ⭐ Selection & Filtering

# %% [markdown]
# # SELECTION IN PANDAS

# %% [markdown]
# # ✅ A) Single Column

# %%
df["Name"]
# Out:
# 0      Neha
# 1      Ravi
# 2     Priya
# 3     Sneha
# 4     Karan
#       ...
# 95     Ravi
# 96    Sneha
# 97    Karan
# 98    Rahul
# 99    Pooja
# Name: Name, Length: 100, dtype: object

# %% [markdown]
# # ✅ B) Multiple Columns

# %%
df[["Age", "Salary"]]
# Out:
#      Age   Salary
# 0   22.0  50653.0
# 1   29.0  69988.0
# 2   40.0  71920.0
# 3   34.0  72905.0
# 4   27.0  31899.0
# ..   ...      ...
# 95  28.0  49939.0
# 96  31.0  72570.0
# 97  36.0  46938.0
# 98  27.0  58011.0
# 99  34.0  75038.0
#
# [100 rows x 2 columns]

# %% [markdown]
# # 2️⃣ Row Selection

# %% [markdown]
# # 🔹 A) loc[] (Label Based Selection)
# - `df.loc[row_label , column_label]`

# %% [markdown]
# ✅ Example 1: First 5 rows

# %%
df.loc[0:4]
# Out:
#    Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0      31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1      47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2      29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3      36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 4      24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
#
#    Performance_Score
# 0                  4
# 1                  2
# 2                  1
# 3                  4
# 4                  1

# %% [markdown]
# ✅ Example 2: Specific row & column

# %%
df.loc[2, "Department"]
# Out:
# 'HR'

# %% [markdown]
# ✅ Example 3: Rows 0-5 & specific columns

# %%
df.loc[0:4, "Salary"]
# Out:
# 0    50653.0
# 1    69988.0
# 2    71920.0
# 3    72905.0
# 4    31899.0
# Name: Salary, dtype: float64

# %% [markdown]
# # 🔹 B) iloc[] (Position Based Selection)
# `df.iloc[row_position , column_position]`

# %% [markdown]
# ✅ Example 1: First 5 rows

# %%
df.iloc[0:5]
# Out:
#    Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0      31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1      47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2      29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3      36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 4      24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
#
#    Performance_Score
# 0                  4
# 1                  2
# 2                  1
# 3                  4
# 4                  1

# %% [markdown]
# ✅ Example 2: Specific row & column

# %%
df.iloc[2, 1]
# Out:
# 'Priya'

# %% [markdown]
# ✅ Example 3: Rows & Columns

# %%
df.iloc[0:3, 1:3]
# Out:
#     Name   Age
# 0   Neha  22.0
# 1   Ravi  29.0
# 2  Priya  40.0

# %% [markdown]
# # 🔷 PART 2: FILTERING IN PANDAS
# 🔹 Filtering kya hota hai?
# - 👉 Condition ke base par rows select karna.

# %% [markdown]
# # 1️⃣ Basic Filtering
# ✅ Salary > 50000

# %%
df[df["Salary"] > 50000]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 5       43  Rahul  23.0    Finance  65085.0   12-12-2021    Delhi
# ..     ...    ...   ...        ...      ...          ...      ...
# 92       3  Rahul  31.0         HR  69668.0   13-10-2020  Chennai
# 94      43  Karan  27.0    Finance  74583.0   19-02-2022   Mumbai
# 96      10  Sneha  31.0      Sales  72570.0   17-01-2021  Kolkata
# 98      12  Rahul  27.0    Finance  58011.0   02-04-2022   Mumbai
# 99      27  Pooja  34.0    Finance  75038.0   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 5                   2
# ..                ...
# ...

# %% [markdown]
# ✅ Department == IT

# %%
df[df["Department"] == 'IT']
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# 23      50   Neha  39.0         IT  62722.0   03-01-2022  Kolkata
# 34      19  Sneha  29.0         IT  59160.0   15-10-2021     Pune
# 38      24  Priya  28.0         IT  51268.0   17-02-2020  Kolkata
# 39      28  Rahul  29.0         IT  52494.0   10-02-2021  Kolkata
# 47      30  Priya  30.0         IT  33405.0   15-11-2021   Mumbai
# 49       1   Amit  26.0         IT  33524.0   28-04-2022  Chennai
# 52      33  Karan  34.0         IT  73498.0   01-06-2021  Chennai
# 58       9  Sneha  33.0         IT  78948.0   02-02-2022    Delhi
# 61      29   Ravi  27.0         IT  38191.0   07-02-2022     Pune
# 62      44   Ravi  37.0         IT  61561.0   22-05-2020     Pune
# 64      40  Rahul  38.0         IT  68535.0   10-12-2020     Pune
# 66      27  Pooja  34.0         IT  37652.0   28-02-2022     Pune
# ...

# %% [markdown]
# # 2️⃣ Multiple Conditions

# %% [markdown]
# ✅ AND Condition (&)

# %%
df[(df["Age"] > 25) & (df["Salary"] > 40000)]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 7       36  Priya  34.0         HR  62662.0   02-10-2021  Chennai
# 9       10  Priya  38.0         HR  73454.0   21-07-2022     Pune
# 10      20   Neha  38.0    Finance  63645.0   20-11-2020    Delhi
# 11      16  Sneha  37.0         HR  79070.0   11-10-2020  Chennai
# 13      15   Neha  26.0    Finance  47550.0   27-09-2021   Mumbai
# 14       4   Neha  40.0      Sales  48924.0   18-05-2021  Chennai
# 23      50   Neha  39.0         IT  62722.0   03-01-2022  Kolkata
# 25      47  Rahul  38.0         HR  66914.0   02-05-2020   Mumbai
# 26       1  Priya  36.0      Sales  77696.0   10-09-2022   Mumbai
# 28      33  Rahul  32.0      Sales  54048.0   18-09-2022    Delhi
# ...

# %% [markdown]
# ✅ OR Condition (|)

# %%
df[(df["Department"] == "IT") | (df["Department"] == "HR")]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# 7       36  Priya  34.0         HR  62662.0   02-10-2021  Chennai
# 9       10  Priya  38.0         HR  73454.0   21-07-2022     Pune
# 11      16  Sneha  37.0         HR  79070.0   11-10-2020  Chennai
# 12      41   Amit  24.0         HR  34481.0   06-05-2022   Mumbai
# 16       8  Karan  36.0         HR  36733.0   29-08-2020   Mumbai
# 19      32  Priya  26.0         HR  34661.0   29-01-2020  Chennai
# 21       8  Karan  32.0         HR  37793.0   22-12-2020    Delhi
# 23      50   Neha  39.0         IT  62722.0   03-01-2022  Kolkata
# 25      47  Rahul  38.0         HR  66914.0   02-05-2020   Mumbai
# 27      37   Ravi  21.0         HR  75765.0   19-10-2021    Delhi
# ...

# %% [markdown]
# 3️⃣ NOT Condition (~)

# %%
df[~(df["Department"] == "IT")]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 5       43  Rahul  23.0    Finance  65085.0   12-12-2021    Delhi
# ..     ...    ...   ...        ...      ...          ...      ...
# 95      27   Ravi  28.0         HR  49939.0   11-01-2021  Chennai
# 96      10  Sneha  31.0      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  36.0      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  27.0    Finance  58011.0   02-04-2022   Mumbai
# 99      27  Pooja  34.0    Finance  75038.0   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 5                   2
# ..                ...
# ...

# %% [markdown]
# 4️⃣ isin() Function

# %%
df[df["Department"].isin(["IT", "HR"])]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# 7       36  Priya  34.0         HR  62662.0   02-10-2021  Chennai
# 9       10  Priya  38.0         HR  73454.0   21-07-2022     Pune
# 11      16  Sneha  37.0         HR  79070.0   11-10-2020  Chennai
# 12      41   Amit  24.0         HR  34481.0   06-05-2022   Mumbai
# 16       8  Karan  36.0         HR  36733.0   29-08-2020   Mumbai
# 19      32  Priya  26.0         HR  34661.0   29-01-2020  Chennai
# 21       8  Karan  32.0         HR  37793.0   22-12-2020    Delhi
# 23      50   Neha  39.0         IT  62722.0   03-01-2022  Kolkata
# 25      47  Rahul  38.0         HR  66914.0   02-05-2020   Mumbai
# 27      37   Ravi  21.0         HR  75765.0   19-10-2021    Delhi
# ...

# %% [markdown]
# 5️⃣ between()

# %%
df[df["Age"].between(25, 35)]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# 7       36  Priya  34.0         HR  62662.0   02-10-2021  Chennai
# 13      15   Neha  26.0    Finance  47550.0   27-09-2021   Mumbai
# 17      44   Amit  25.0      Sales  57969.0   31-08-2020  Chennai
# 19      32  Priya  26.0         HR  34661.0   29-01-2020  Chennai
# 21       8  Karan  32.0         HR  37793.0   22-12-2020    Delhi
# 24       6  Priya  26.0      Sales  34947.0   19-11-2020    Delhi
# 28      33  Rahul  32.0      Sales  54048.0   18-09-2022    Delhi
# 29      35   Amit  34.0      Sales  51314.0   29-05-2022   Mumbai
# 31      12   Ravi  32.0      Sales  60430.0   22-01-2022     Pune
# 32       4  Sneha  32.0      Sales  55851.0   07-04-2021   Mumbai
# ...

# %% [markdown]
# 6️⃣ String Filtering

# %% [markdown]
# Case insensitive:

# %% [markdown]
# # 📝 🔥 PRACTICE SET (Level Wise)

# %% [markdown]
# # 🟢 LEVEL 1 – Basic Selection
# Q1️⃣ Sirf “Name” column select karo.

# %%
df["Name"]
# Out:
# 0      Neha
# 1      Ravi
# 2     Priya
# 3     Sneha
# 4     Karan
#       ...
# 95     Ravi
# 96    Sneha
# 97    Karan
# 98    Rahul
# 99    Pooja
# Name: Name, Length: 100, dtype: object

# %% [markdown]
# Q2️⃣ “Name” aur “Salary” dono columns select karo.

# %%
df[["Name", "Salary"]]
# Out:
#      Name   Salary
# 0    Neha  50653.0
# 1    Ravi  69988.0
# 2   Priya  71920.0
# 3   Sneha  72905.0
# 4   Karan  31899.0
# ..    ...      ...
# 95   Ravi  49939.0
# 96  Sneha  72570.0
# 97  Karan  46938.0
# 98  Rahul  58011.0
# 99  Pooja  75038.0
#
# [100 rows x 2 columns]

# %% [markdown]
# Q3️⃣ First 10 rows show karo.

# %%
df.loc[0:9]
# Out:
#    Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0      31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1      47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2      29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3      36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 4      24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# 5      43  Rahul  23.0    Finance  65085.0   12-12-2021    Delhi
# 6       5  Pooja  22.0      Sales  68706.0   25-11-2020     Pune
# 7      36  Priya  34.0         HR  62662.0   02-10-2021  Chennai
# 8      35  Sneha  21.0    Finance  72945.0   10-01-2022  Chennai
# 9      10  Priya  38.0         HR  73454.0   21-07-2022     Pune
#
#    Performance_Score
# 0                  4
# 1                  2
# 2                  1
# 3                  4
# 4                  1
# 5                  2
# 6                  1
# 7                  2
# 8                  2
# 9                  4

# %% [markdown]
# Q4️⃣ 5th row ka “Department” value nikalo.

# %%
df.loc[4, "Department"]
# Out:
# 'IT'

# %% [markdown]
# # 🟡 LEVEL 2 – Basic Filtering
# Q5️⃣ Salary > 60000 wale employees dikhao.

# %%
df[df["Salary"] > 60000]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 5       43  Rahul  23.0    Finance  65085.0   12-12-2021    Delhi
# 6        5  Pooja  22.0      Sales  68706.0   25-11-2020     Pune
# 7       36  Priya  34.0         HR  62662.0   02-10-2021  Chennai
# 8       35  Sneha  21.0    Finance  72945.0   10-01-2022  Chennai
# 9       10  Priya  38.0         HR  73454.0   21-07-2022     Pune
# 10      20   Neha  38.0    Finance  63645.0   20-11-2020    Delhi
# 11      16  Sneha  37.0         HR  79070.0   11-10-2020  Chennai
# 23      50   Neha  39.0         IT  62722.0   03-01-2022  Kolkata
# 25      47  Rahul  38.0         HR  66914.0   02-05-2020   Mumbai
# 26       1  Priya  36.0      Sales  77696.0   10-09-2022   Mumbai
# ...

# %% [markdown]
# Q6️⃣ Department == "IT" wale employees dikhao.

# %%
df[df["Department"] == "IT"]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# 23      50   Neha  39.0         IT  62722.0   03-01-2022  Kolkata
# 34      19  Sneha  29.0         IT  59160.0   15-10-2021     Pune
# 38      24  Priya  28.0         IT  51268.0   17-02-2020  Kolkata
# 39      28  Rahul  29.0         IT  52494.0   10-02-2021  Kolkata
# 47      30  Priya  30.0         IT  33405.0   15-11-2021   Mumbai
# 49       1   Amit  26.0         IT  33524.0   28-04-2022  Chennai
# 52      33  Karan  34.0         IT  73498.0   01-06-2021  Chennai
# 58       9  Sneha  33.0         IT  78948.0   02-02-2022    Delhi
# 61      29   Ravi  27.0         IT  38191.0   07-02-2022     Pune
# 62      44   Ravi  37.0         IT  61561.0   22-05-2020     Pune
# 64      40  Rahul  38.0         IT  68535.0   10-12-2020     Pune
# 66      27  Pooja  34.0         IT  37652.0   28-02-2022     Pune
# ...

# %% [markdown]
# Q7️⃣ Age < 30 wale employees show karo.

# %%
df[df["Age"] < 30]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# 5       43  Rahul  23.0    Finance  65085.0   12-12-2021    Delhi
# 6        5  Pooja  22.0      Sales  68706.0   25-11-2020     Pune
# 8       35  Sneha  21.0    Finance  72945.0   10-01-2022  Chennai
# 12      41   Amit  24.0         HR  34481.0   06-05-2022   Mumbai
# 13      15   Neha  26.0    Finance  47550.0   27-09-2021   Mumbai
# 15      15  Rahul  21.0    Finance  55977.0   01-08-2020     Pune
# 17      44   Amit  25.0      Sales  57969.0   31-08-2020  Chennai
# 18       5  Pooja  23.0    Finance  49144.0   20-03-2022   Mumbai
# 19      32  Priya  26.0         HR  34661.0   29-01-2020  Chennai
# 20      35  Rahul  22.0    Finance  48613.0   15-03-2022     Pune
# ...

# %% [markdown]
# # 🟠 LEVEL 3 – Multiple Conditions
# Q8️⃣ IT department me Salary > 50000 wale employees.

# %%
df.loc[
    (df["Department"] == "IT") & (df["Salary"] > 50000)
]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 23      50   Neha  39.0         IT  62722.0   03-01-2022  Kolkata
# 34      19  Sneha  29.0         IT  59160.0   15-10-2021     Pune
# 38      24  Priya  28.0         IT  51268.0   17-02-2020  Kolkata
# 39      28  Rahul  29.0         IT  52494.0   10-02-2021  Kolkata
# 52      33  Karan  34.0         IT  73498.0   01-06-2021  Chennai
# 58       9  Sneha  33.0         IT  78948.0   02-02-2022    Delhi
# 62      44   Ravi  37.0         IT  61561.0   22-05-2020     Pune
# 64      40  Rahul  38.0         IT  68535.0   10-12-2020     Pune
# 67      23   Ravi  26.0         IT  57759.0   12-11-2021  Kolkata
# 74      39  Sneha  36.0         IT  79253.0   14-02-2022  Kolkata
# 76      12  Sneha  27.0         IT  75298.0   11-01-2021  Kolkata
#
#     Performance_Score
# 23                  4
# 34                  5
# 38                  1
# 39                  4
# 52                  1
# 58                  4
# ...

# %% [markdown]
# Q9️⃣ HR ya Sales department ke employees.

# %%
df.loc[
    (df["Department"] == "HR") | (df["Department"] == "Sales")
]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 6        5  Pooja  22.0      Sales  68706.0   25-11-2020     Pune
# 7       36  Priya  34.0         HR  62662.0   02-10-2021  Chennai
# 9       10  Priya  38.0         HR  73454.0   21-07-2022     Pune
# 11      16  Sneha  37.0         HR  79070.0   11-10-2020  Chennai
# 12      41   Amit  24.0         HR  34481.0   06-05-2022   Mumbai
# 14       4   Neha  40.0      Sales  48924.0   18-05-2021  Chennai
# 16       8  Karan  36.0         HR  36733.0   29-08-2020   Mumbai
# 17      44   Amit  25.0      Sales  57969.0   31-08-2020  Chennai
# 19      32  Priya  26.0         HR  34661.0   29-01-2020  Chennai
# 21       8  Karan  32.0         HR  37793.0   22-12-2020    Delhi
# ...

# %% [markdown]
# Q🔟 Salary 40000 se 70000 ke beech wale employees.

# %%
df.loc[df["Salary"].between(40000, 70000)]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 5       43  Rahul  23.0    Finance  65085.0   12-12-2021    Delhi
# 6        5  Pooja  22.0      Sales  68706.0   25-11-2020     Pune
# 7       36  Priya  34.0         HR  62662.0   02-10-2021  Chennai
# ..     ...    ...   ...        ...      ...          ...      ...
# 91      10  Rahul  25.0      Sales  52292.0   21-04-2021    Delhi
# 92       3  Rahul  31.0         HR  69668.0   13-10-2020  Chennai
# 95      27   Ravi  28.0         HR  49939.0   11-01-2021  Chennai
# 97      30  Karan  36.0      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  27.0    Finance  58011.0   02-04-2022   Mumbai
#
#     Performance_Score
# 0                   4
# 1                   2
# 5                   2
# 6                   1
# 7                   2
# ..                ...
# ...

# %% [markdown]
# # 🔵 LEVEL 4 – Advanced Filtering
# Q1️⃣ Name me letter "a" wale employees

# %%
df.loc[df["Name"].str.contains("a")]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 4       24  Karan  27.0         IT  31899.0   28-07-2022  Kolkata
# ..     ...    ...   ...        ...      ...          ...      ...
# 95      27   Ravi  28.0         HR  49939.0   11-01-2021  Chennai
# 96      10  Sneha  31.0      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  36.0      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  27.0    Finance  58011.0   02-04-2022   Mumbai
# 99      27  Pooja  34.0    Finance  75038.0   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# ...

# %% [markdown]
# Q2️⃣ IT department ke alawa sab employees.

# %%
df.loc[~(df["Department"] == "IT")]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 0       31   Neha  22.0    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR  71920.0   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales  72905.0   15-11-2020    Delhi
# 5       43  Rahul  23.0    Finance  65085.0   12-12-2021    Delhi
# ..     ...    ...   ...        ...      ...          ...      ...
# 95      27   Ravi  28.0         HR  49939.0   11-01-2021  Chennai
# 96      10  Sneha  31.0      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  36.0      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  27.0    Finance  58011.0   02-04-2022   Mumbai
# 99      27  Pooja  34.0    Finance  75038.0   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 5                   2
# ..                ...
# ...

# %% [markdown]
# Q3️⃣ Top 5 highest salary wale employees.

# %% [markdown]
# Q4️⃣ Duplicate Emp_ID wale employees show karo.

# %% [markdown]
# # 🔴 LEVEL 5 – Real Interview Type
# Q5️⃣ IT department me:
# - Age > 30
# - Salary > 60000
# Wale employees show karo.

# %%
df.loc[
    (df["Department"] == "IT") &
    (df["Age"] > 30) &
    (df["Salary"] > 60000)
]
# Out:
#     Emp_ID   Name   Age Department   Salary Joining_Date     City  \
# 23      50   Neha  39.0         IT  62722.0   03-01-2022  Kolkata
# 52      33  Karan  34.0         IT  73498.0   01-06-2021  Chennai
# 58       9  Sneha  33.0         IT  78948.0   02-02-2022    Delhi
# 62      44   Ravi  37.0         IT  61561.0   22-05-2020     Pune
# 64      40  Rahul  38.0         IT  68535.0   10-12-2020     Pune
# 74      39  Sneha  36.0         IT  79253.0   14-02-2022  Kolkata
#
#     Performance_Score
# 23                  4
# 52                  1
# 58                  4
# 62                  3
# 64                  1
# 74                  4
