# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"c:\Pandas practice Data\01_Data.xlsx")
df
# Out:
#     Emp_ID   Name      Age Department   Salary Joining_Date     City  \
# 0       31   Neha  Unknown    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi       29         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya       40         HR      NaN   18-09-2022     Pune
# 3       36  Sneha       34      Sales      NaN   15-11-2020    Delhi
# 4       24  Karan       27         IT  31899.0   28-07-2022  Kolkata
# ..     ...    ...      ...        ...      ...          ...      ...
# 95      27   Ravi       28         HR      NaN   11-01-2021  Chennai
# 96      10  Sneha  Unknown      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  Unknown      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  Unknown    Finance      NaN   02-04-2022   Mumbai
# 99      27  Pooja  Unknown    Finance      NaN   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# 95                  4
# 96                  1
# 97                  5
# 98                  4
# 99                  2
#
# [100 rows x 8 columns]

# %% [markdown]
# # Basic Data Inspection

# %%
df.head()
# Out:
#    Emp_ID   Name      Age Department   Salary Joining_Date     City  \
# 0      31   Neha  Unknown    Finance  50653.0   18-12-2020    Delhi
# 1      47   Ravi       29         HR  69988.0   18-10-2020   Mumbai
# 2      29  Priya       40         HR      NaN   18-09-2022     Pune
# 3      36  Sneha       34      Sales      NaN   15-11-2020    Delhi
# 4      24  Karan       27         IT  31899.0   28-07-2022  Kolkata
#
#    Performance_Score
# 0                  4
# 1                  2
# 2                  1
# 3                  4
# 4                  1

# %%
df.tail()
# Out:
#     Emp_ID   Name      Age Department   Salary Joining_Date     City  \
# 95      27   Ravi       28         HR      NaN   11-01-2021  Chennai
# 96      10  Sneha  Unknown      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  Unknown      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  Unknown    Finance      NaN   02-04-2022   Mumbai
# 99      27  Pooja  Unknown    Finance      NaN   23-08-2022  Chennai
#
#     Performance_Score
# 95                  4
# 96                  1
# 97                  5
# 98                  4
# 99                  2

# %%
df.shape
# Out:
# (100, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Emp_ID             100 non-null    int64
#  1   Name               100 non-null    object
#  2   Age                100 non-null    object
#  3   Department         100 non-null    object
#  4   Salary             53 non-null     float64
#  5   Joining_Date       100 non-null    object
#  6   City               100 non-null    object
#  7   Performance_Score  100 non-null    int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
df.describe()
# Out:
#            Emp_ID        Salary  Performance_Score
# count  100.000000     53.000000         100.000000
# mean    24.310000  56121.264151           3.000000
# std     14.765299  15065.095846           1.497473
# min      1.000000  31899.000000           1.000000
# 25%     10.000000  40528.000000           1.750000
# 50%     25.000000  57969.000000           3.000000
# 75%     36.000000  69668.000000           4.000000
# max     50.000000  79253.000000           5.000000

# %%
df.columns
# Out:
# Index(['Emp_ID', 'Name', 'Age', 'Department', 'Salary', 'Joining_Date', 'City',
#        'Performance_Score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Emp_ID                 int64
# Name                  object
# Age                   object
# Department            object
# Salary               float64
# Joining_Date          object
# City                  object
# Performance_Score      int64
# dtype: object

# %% [markdown]
# # Duplicate

# %%
df.isnull().sum()
# Out:
# Emp_ID                0
# Name                  0
# Age                   0
# Department            0
# Salary               47
# Joining_Date          0
# City                  0
# Performance_Score     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Convert INT

# %%
df["Salary"] = df["Salary"].round().astype("Int64")
df
# Out:
#     Emp_ID   Name      Age Department  Salary Joining_Date     City  \
# 0       31   Neha  Unknown    Finance   50653   18-12-2020    Delhi
# 1       47   Ravi       29         HR   69988   18-10-2020   Mumbai
# 2       29  Priya       40         HR   67724   18-09-2022     Pune
# 3       36  Sneha       34      Sales   63039   15-11-2020    Delhi
# 4       24  Karan       27         IT   31899   28-07-2022  Kolkata
# ..     ...    ...      ...        ...     ...          ...      ...
# 95      27   Ravi       28         HR   40913   11-01-2021  Chennai
# 96      10  Sneha  Unknown      Sales   72570   17-01-2021  Kolkata
# 97      30  Karan  Unknown      Sales   46938   18-12-2020  Kolkata
# 98      12  Rahul  Unknown    Finance   53465   02-04-2022   Mumbai
# 99      27  Pooja  Unknown    Finance   69287   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# 95                  4
# 96                  1
# 97                  5
# 98                  4
# 99                  2
#
# [100 rows x 8 columns]

# %% [markdown]
# # Fill Missing Value

# %%
df["Salary"] = df["Salary"].apply(
    lambda x: np.random.randint(31899, 79253) if pd.isna(x) else x
)
df
# Out:
#     Emp_ID   Name      Age Department   Salary Joining_Date     City  \
# 0       31   Neha  Unknown    Finance  50653.0   18-12-2020    Delhi
# 1       47   Ravi       29         HR  69988.0   18-10-2020   Mumbai
# 2       29  Priya       40         HR  67724.0   18-09-2022     Pune
# 3       36  Sneha       34      Sales  63039.0   15-11-2020    Delhi
# 4       24  Karan       27         IT  31899.0   28-07-2022  Kolkata
# ..     ...    ...      ...        ...      ...          ...      ...
# 95      27   Ravi       28         HR  40913.0   11-01-2021  Chennai
# 96      10  Sneha  Unknown      Sales  72570.0   17-01-2021  Kolkata
# 97      30  Karan  Unknown      Sales  46938.0   18-12-2020  Kolkata
# 98      12  Rahul  Unknown    Finance  53465.0   02-04-2022   Mumbai
# 99      27  Pooja  Unknown    Finance  69287.0   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# 95                  4
# 96                  1
# 97                  5
# 98                  4
# 99                  2
#
# [100 rows x 8 columns]

# %% [markdown]
# # Age Fill Missing value
# - "unknown" ko NaN me convert karo

# %%
df["Age"] = df["Age"].replace("Unknown", np.nan)
df
# Out:
#     Emp_ID   Name   Age Department  Salary Joining_Date     City  \
# 0       31   Neha   NaN    Finance   50653   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR   69988   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR   67724   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales   63039   15-11-2020    Delhi
# 4       24  Karan  27.0         IT   31899   28-07-2022  Kolkata
# ..     ...    ...   ...        ...     ...          ...      ...
# 95      27   Ravi  28.0         HR   40913   11-01-2021  Chennai
# 96      10  Sneha   NaN      Sales   72570   17-01-2021  Kolkata
# 97      30  Karan   NaN      Sales   46938   18-12-2020  Kolkata
# 98      12  Rahul   NaN    Finance   53465   02-04-2022   Mumbai
# 99      27  Pooja   NaN    Finance   69287   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# 95                  4
# 96                  1
# 97                  5
# 98                  4
# 99                  2
#
# [100 rows x 8 columns]

# %% [markdown]
# # Age ko numeric type me convert karo

# %%
df["Age"] = pd.to_numeric(df["Age"])
df
# Out:
#     Emp_ID   Name   Age Department  Salary Joining_Date     City  \
# 0       31   Neha   NaN    Finance   50653   18-12-2020    Delhi
# 1       47   Ravi  29.0         HR   69988   18-10-2020   Mumbai
# 2       29  Priya  40.0         HR   67724   18-09-2022     Pune
# 3       36  Sneha  34.0      Sales   63039   15-11-2020    Delhi
# 4       24  Karan  27.0         IT   31899   28-07-2022  Kolkata
# ..     ...    ...   ...        ...     ...          ...      ...
# 95      27   Ravi  28.0         HR   40913   11-01-2021  Chennai
# 96      10  Sneha   NaN      Sales   72570   17-01-2021  Kolkata
# 97      30  Karan   NaN      Sales   46938   18-12-2020  Kolkata
# 98      12  Rahul   NaN    Finance   53465   02-04-2022   Mumbai
# 99      27  Pooja   NaN    Finance   69287   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# 95                  4
# 96                  1
# 97                  5
# 98                  4
# 99                  2
#
# [100 rows x 8 columns]

# %% [markdown]
# # Fill Missing Value

# %%
df["Age"] = df["Age"].apply(
    lambda x: np.random.randint(21, 40) if pd.isna(x) else x
)
df
# Out:
#     Emp_ID   Name      Age Department  Salary Joining_Date     City  \
# 0       31   Neha  72705.0    Finance   50653   18-12-2020    Delhi
# 1       47   Ravi     29.0         HR   69988   18-10-2020   Mumbai
# 2       29  Priya     40.0         HR   67724   18-09-2022     Pune
# 3       36  Sneha     34.0      Sales   63039   15-11-2020    Delhi
# 4       24  Karan     27.0         IT   31899   28-07-2022  Kolkata
# ..     ...    ...      ...        ...     ...          ...      ...
# 95      27   Ravi     28.0         HR   40913   11-01-2021  Chennai
# 96      10  Sneha  56113.0      Sales   72570   17-01-2021  Kolkata
# 97      30  Karan  61774.0      Sales   46938   18-12-2020  Kolkata
# 98      12  Rahul  51667.0    Finance   53465   02-04-2022   Mumbai
# 99      27  Pooja  40765.0    Finance   69287   23-08-2022  Chennai
#
#     Performance_Score
# 0                   4
# 1                   2
# 2                   1
# 3                   4
# 4                   1
# ..                ...
# 95                  4
# 96                  1
# 97                  5
# 98                  4
# 99                  2
#
# [100 rows x 8 columns]
