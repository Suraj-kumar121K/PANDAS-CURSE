# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Load the dataset using Pandas.

# %%
df = pd.read_excel(r"C:\Users\Anish Kumar\Downloads\pandas_data.xlsx")

# %%
df
# Out:
#     Employee_ID    Name    Age       City Department    Salary Joining_Date  \
# 0             1   Suraj   22.0     mumbai         IT   40000.0   15/02/2023
# 1             2  Anjali   25.0        NaN    Finance   25000.0   2023-01-15
# 2             3   Priya   30.0       Pune      sales   25000.0          NaN
# 3             4  Anjali    NaN     Mumbai    Finance   45000.0   2023-01-15
# 4             5   Pooja    NaN     mumbai         IT   40000.0   2022/03/20
# 5             6   Suraj    NaN      delhi         HR       NaN          NaN
# 6             7    Amit  150.0       Pune      Sales       NaN   2023-01-15
# 7             8    Neha    NaN        NaN         IT   30000.0   2023-01-15
# 8             9    Neha   25.0     Mumbai        NaN   30000.0   01-04-2024
# 9            10   Vikas    NaN      DELHI         HR       NaN   15/02/2023
# 10           11   Suraj   28.0       Pune         it   40000.0   15/02/2023
# ...

# %% [markdown]
# 2. Display the first 5 rows of the dataset.

# %%
df.head(5)
# Out:
#    Employee_ID    Name   Age    City Department   Salary Joining_Date  \
# 0            1   Suraj  22.0  mumbai         IT  40000.0   15/02/2023
# 1            2  Anjali  25.0     NaN    Finance  25000.0   2023-01-15
# 2            3   Priya  30.0    Pune      sales  25000.0          NaN
# 3            4  Anjali   NaN  Mumbai    Finance  45000.0   2023-01-15
# 4            5   Pooja   NaN  mumbai         IT  40000.0   2022/03/20
#
#              Email
# 0  suraj@gmail.com
# 1  suraj@gmail.com
# 2  priya@gmail.com
# 3  rahul@gmail.com
# 4  suraj@gmail.com

# %% [markdown]
# 3. Display the last 5 rows of the dataset.

# %%
df.tail(5)
# Out:
#     Employee_ID    Name    Age       City Department   Salary Joining_Date  \
# 55            6   Suraj    NaN      delhi         HR      NaN          NaN
# 56           11   Suraj   28.0       Pune         it  40000.0   15/02/2023
# 57           21  Anjali   28.0       Pune      Sales  45000.0          NaN
# 58           59    Neha   28.0      delhi    Finance  25000.0   01-04-2024
# 59           60   Priya  150.0  Bangalore         HR  40000.0   15/02/2023
#
#                Email
# 55    neha@gmail.com
# 56   vikas@gmail.com
# 57  anjali@gmail.com
# 58   priya@gmail.com
# 59    amit@gmail.com

# %% [markdown]
# 4. Check the shape of the dataset.

# %%
df.shape
# Out:
# (60, 8)

# %% [markdown]
# 5. Check the column names.

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'City', 'Department', 'Salary',
#        'Joining_Date', 'Email'],
#       dtype='str')

# %% [markdown]
# 6. Check the data types of all columns.

# %%
df.dtypes
# Out:
# Employee_ID       int64
# Name                str
# Age             float64
# City                str
# Department          str
# Salary          float64
# Joining_Date        str
# Email               str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Employee_ID   60 non-null     int64
#  1   Name          60 non-null     str
#  2   Age           45 non-null     float64
#  3   City          56 non-null     str
#  4   Department    55 non-null     str
#  5   Salary        47 non-null     float64
#  6   Joining_Date  39 non-null     str
#  7   Email         60 non-null     str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 3.9 KB

# %% [markdown]
# 7. Find the total number of missing values in each column.

# %%
df.isna().sum()
# Out:
# Employee_ID      0
# Name             0
# Age             15
# City             4
# Department       5
# Salary          13
# Joining_Date    21
# Email            0
# dtype: int64

# %% [markdown]
# 8. Replace "N/A" values with NaN.

# %%
df.replace("N/A", np.nan, inplace=True)
# Out:
#     Employee_ID    Name    Age       City Department    Salary Joining_Date  \
# 0             1   Suraj   22.0     mumbai         IT   40000.0   15/02/2023
# 1             2  Anjali   25.0        NaN    Finance   25000.0   2023-01-15
# 2             3   Priya   30.0       Pune      sales   25000.0          NaN
# 3             4  Anjali    NaN     Mumbai    Finance   45000.0   2023-01-15
# 4             5   Pooja    NaN     mumbai         IT   40000.0   2022/03/20
# 5             6   Suraj    NaN      delhi         HR       NaN          NaN
# 6             7    Amit  150.0       Pune      Sales       NaN   2023-01-15
# 7             8    Neha    NaN        NaN         IT   30000.0   2023-01-15
# 8             9    Neha   25.0     Mumbai        NaN   30000.0   01-04-2024
# 9            10   Vikas    NaN      DELHI         HR       NaN   15/02/2023
# 10           11   Suraj   28.0       Pune         it   40000.0   15/02/2023
# ...

# %% [markdown]
# 9. Find duplicate rows in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %% [markdown]
# 10. Find duplicate rows in the dataset.

# %%
df[df.duplicated()]
# Out:
#     Employee_ID    Name   Age   City Department   Salary Joining_Date  \
# 55            6   Suraj   NaN  delhi         HR      NaN          NaN
# 56           11   Suraj  28.0   Pune         it  40000.0   15/02/2023
# 57           21  Anjali  28.0   Pune      Sales  45000.0          NaN
#
#                Email
# 55    neha@gmail.com
# 56   vikas@gmail.com
# 57  anjali@gmail.com

# %% [markdown]
# 11. Remove duplicate rows.

# %%
df.drop_duplicates()
# Out:
#     Employee_ID    Name    Age       City Department    Salary Joining_Date  \
# 0             1   Suraj   22.0     mumbai         IT   40000.0   15/02/2023
# 1             2  Anjali   25.0        NaN    Finance   25000.0   2023-01-15
# 2             3   Priya   30.0       Pune      sales   25000.0          NaN
# 3             4  Anjali    NaN     Mumbai    Finance   45000.0   2023-01-15
# 4             5   Pooja    NaN     mumbai         IT   40000.0   2022/03/20
# 5             6   Suraj    NaN      delhi         HR       NaN          NaN
# 6             7    Amit  150.0       Pune      Sales       NaN   2023-01-15
# 7             8    Neha    NaN        NaN         IT   30000.0   2023-01-15
# 8             9    Neha   25.0     Mumbai        NaN   30000.0   01-04-2024
# 9            10   Vikas    NaN      DELHI         HR       NaN   15/02/2023
# 10           11   Suraj   28.0       Pune         it   40000.0   15/02/2023
# ...

# %% [markdown]
# 12. Fill missing values in the Age column using the median.

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

# %% [markdown]
# 13. Fill missing values in the Salary column using the median.

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].median())

# %% [markdown]
# 14. Fill missing values in the City column using the mode.

# %%
df["City"] = df["City"].fillna(df["City"].mode()[0])

# %% [markdown]
# 15. Fill missing values in the Department column using the mode.

# %%
df["Department"] = df["Department"].fillna(df["Department"].mode()[0])

# %% [markdown]
# 15. Convert the Age column to numeric data type.
# - pd.to_numeric() → values ko numeric type mein convert karta hai

# %%
df["Age"] = pd.to_numeric(df["Age"]).apply(int)

# %% [markdown]
# 16. Convert the Salary column to numeric data type.

# %%
df["Salary"] = pd.to_numeric(df["Salary"]).apply(int)

# %% [markdown]
# 16. Check all unique values in the City column.

# %%
df["City"].unique()
# Out:
# <StringArray>
# [   'mumbai',      'Pune',    'Mumbai',     'delhi',     'DELHI', 'Bengaluru',
#    'Kolkata', 'Bangalore',     'Delhi']
# Length: 9, dtype: str

# %% [markdown]
# 17. Standardize city names such as delhi, DELHI, and Delhi into one format.
# - .str.title() → Har word ka first letter capital karta hai.

# %%
df["City"] = df["City"].str.title()

# %% [markdown]
# 18. Check all unique values in the Department column.

# %%
df["Department"].unique()
# Out:
# <StringArray>
# ['IT', 'Finance', 'sales', 'HR', 'Sales', 'it']
# Length: 6, dtype: str

# %% [markdown]
# 19. Standardize department names such as sales and Sales.

# %%
df["Department"] = df["Department"].str.title()

# %% [markdown]
# 19. Remove extra spaces from all text columns.

# %%
for col in df.select_dtypes(include="object"):
    df[col] = df[col].str.strip()
# Out:
# C:\Users\Anish Kumar\AppData\Local\Temp\ipykernel_31152\3483331084.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include="object"):

# %% [markdown]
# 20. Convert the Joining_Date column into datetime format.

# %%
df["Joining_Date"] = pd.to_datetime(
    df["Joining_Date"],
    format="mixed"
).dt.strftime("%d/%m/%Y")

# %%
df["Joining_Date"] = pd.to_datetime(
    df["Joining_Date"],
    format="mixed"
)

df["Joining_Date"] = df["Joining_Date"].fillna(
    df["Joining_Date"].median()
)

df["Joining_Date"] = df["Joining_Date"].dt.strftime("%d/%m/%Y")

# %%
df
# Out:
#     Employee_ID    Name  Age       City Department  Salary Joining_Date  \
# 0             1   Suraj   22     Mumbai         It   40000   15/02/2023
# 1             2  Anjali   25       Pune    Finance   25000   15/01/2023
# 2             3   Priya   30       Pune      Sales   25000   15/02/2023
# 3             4  Anjali   28     Mumbai    Finance   45000   15/01/2023
# 4             5   Pooja   28     Mumbai         It   40000   20/03/2022
# 5             6   Suraj   28      Delhi         Hr   40000   15/02/2023
# 6             7    Amit  150       Pune      Sales   40000   15/01/2023
# 7             8    Neha   28       Pune         It   30000   15/01/2023
# 8             9    Neha   25     Mumbai    Finance   30000   01/04/2024
# 9            10   Vikas   28      Delhi         Hr   40000   15/02/2023
# 10           11   Suraj   28       Pune         It   40000   15/02/2023
# 11           12   Pooja   35       Pune         It   40000   15/01/2023
# ...
