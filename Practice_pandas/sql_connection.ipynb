# %%
import pyodbc
import pandas as pd

# %%
conn = pyodbc.connect(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=localhost\\SQLEXPRESS;"
    "DATABASE=Excel;"
    "UID=AS;"
    "PWD=Sur7aj6@;"
    "Encrypt=yes;"
    "TrustServerCertificate=yes;"
)

print("✅ SQL Server Connected Successfully!")
# Out:
# ✅ SQL Server Connected Successfully!

# %%
df = pd.read_sql("SELECT * FROM Employee_Data", conn)
# Out:
# C:\Users\Anish Kumar\AppData\Local\Temp\ipykernel_29572\2263573685.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM Employee_Data", conn)

# %%
df.head(5)
# Out:
#   Employee_ID Employee_Name  Department Employee_City  Salary
# 0       E0001  Aarav Sharma          HR         Delhi   68617
# 1       E0002  Vivaan Kumar  Operations     Bengaluru   34695
# 2       E0003  Aditya Singh  Operations       Chennai   60380
# 3       E0004   Arjun Verma     Support       Kolkata   44763
# 4       E0005   Rahul Gupta       Sales         Delhi   51513

# %%
df.shape
# Out:
# (500, 5)

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Employee_Name', 'Department', 'Employee_City',
#        'Salary'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee_ID    500 non-null    str
#  1   Employee_Name  500 non-null    str
#  2   Department     500 non-null    str
#  3   Employee_City  500 non-null    str
#  4   Salary         500 non-null    int64
# dtypes: int64(1), str(4)
# memory usage: 19.7 KB

# %%
cd = pd.read_sql("SELECT * FROM Customer_Data", conn)
# Out:
# C:\Users\Anish Kumar\AppData\Local\Temp\ipykernel_29572\2193415839.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cd = pd.read_sql("SELECT * FROM Customer_Data", conn)

# %%
cd.head(5)
# Out:
#   Customer_ID Customer_Name       City Gender  Age
# 0    CUST0001  Aarav Sharma     Mumbai   Male   35
# 1    CUST0002  Vivaan Kumar    Gurgaon   Male   26
# 2    CUST0003  Aditya Singh     Mumbai   Male   55
# 3    CUST0004   Arjun Verma  Hyderabad   Male   19
# 4    CUST0005   Rahul Gupta     Mumbai   Male   32

# %%
cd.shape
# Out:
# (500, 5)

# %%
cd.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'City', 'Gender', 'Age'], dtype='str')

# %%
cd.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    500 non-null    str
#  1   Customer_Name  500 non-null    str
#  2   City           500 non-null    str
#  3   Gender         500 non-null    str
#  4   Age            500 non-null    int64
# dtypes: int64(1), str(4)
# memory usage: 19.7 KB

# %%
od = pd.read_sql("SELECT * FROM Order_data", conn)
# Out:
# C:\Users\Anish Kumar\AppData\Local\Temp\ipykernel_29572\623865056.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   od = pd.read_sql("SELECT * FROM Order_data", conn)

# %%
od.head(5)
# Out:
#   Order_ID  Order_Date Customer_ID Product_ID Employee_ID  Quantity  Sales  \
# 0  ORD0001  2025-07-29    CUST0397      P0174       E0348        10   7363
# 1  ORD0002  2025-02-03    CUST0169      P0049       E0286         7  37743
# 2  ORD0003  2025-06-20    CUST0042      P0299       E0340         3  46351
# 3  ORD0004  2025-03-08    CUST0305      P0363       E0481         2  41077
# 4  ORD0005  2025-03-07    CUST0344      P0360       E0425         9  12749
#
#   Order_Status      Channel Payment_Method
# 0    Cancelled  Distributor            UPI
# 1      Pending  Distributor           Card
# 2      Pending  Distributor  Bank Transfer
# 3    Cancelled        Store            UPI
# 4    Cancelled  Distributor  Bank Transfer

# %%
od.shape
# Out:
# (500, 10)

# %%
od.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Product_ID', 'Employee_ID',
#        'Quantity', 'Sales', 'Order_Status', 'Channel', 'Payment_Method'],
#       dtype='str')

# %%
od.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        500 non-null    str
#  1   Order_Date      500 non-null    object
#  2   Customer_ID     500 non-null    str
#  3   Product_ID      500 non-null    str
#  4   Employee_ID     500 non-null    str
#  5   Quantity        500 non-null    int64
#  6   Sales           500 non-null    int64
#  7   Order_Status    500 non-null    str
#  8   Channel         500 non-null    str
#  9   Payment_Method  500 non-null    str
# dtypes: int64(2), object(1), str(7)
# memory usage: 39.2+ KB

# %%
pd = pd.read_sql("SELECT * FROM Product_Data", conn)
# Out:
# C:\Users\Anish Kumar\AppData\Local\Temp\ipykernel_29572\723357632.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd = pd.read_sql("SELECT * FROM Product_Data", conn)

# %%
pd.head(5)
# Out:
#   Product_ID Product_Name         Category  Unit_Price Product_Status
# 0      P0001        Shirt  Office Supplies       49214       Inactive
# 1      P0002          Pen        Furniture       12251         Active
# 2      P0003     Keyboard        Furniture       43586       Inactive
# 3      P0004      Monitor        Furniture       11138       Inactive
# 4      P0005      Monitor      Electronics        4380       Inactive

# %%
pd.shape
# Out:
# (500, 5)

# %%
pd.columns
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Unit_Price',
#        'Product_Status'],
#       dtype='str')

# %%
pd.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Product_ID      500 non-null    str
#  1   Product_Name    500 non-null    str
#  2   Category        500 non-null    str
#  3   Unit_Price      500 non-null    int64
#  4   Product_Status  500 non-null    str
# dtypes: int64(1), str(4)
# memory usage: 19.7 KB

# %%
print("Customer:", df.columns.tolist())
print("Employee:", cd.columns.tolist())
print("Order:", od.columns.tolist())
print("Product:", pd.columns.tolist())
# Out:
# Customer: ['Employee_ID', 'Employee_Name', 'Department', 'Employee_City', 'Salary']
# Employee: ['Customer_ID', 'Customer_Name', 'City', 'Gender', 'Age']
# Order: ['Order_ID', 'Order_Date', 'Customer_ID', 'Product_ID', 'Employee_ID', 'Quantity', 'Sales', 'Order_Status', 'Channel', 'Payment_Method']
# Product: ['Product_ID', 'Product_Name', 'Category', 'Unit_Price', 'Product_Status']

# %% [markdown]
# 1. 4 table ,me sa,e lam kiya hu

# %%
cd["Customer_ID"].unique()
# Out:
# <StringArray>
# ['CUST0001', 'CUST0002', 'CUST0003', 'CUST0004', 'CUST0005', 'CUST0006',
#  'CUST0007', 'CUST0008', 'CUST0009', 'CUST0010',
#  ...
#  'CUST0491', 'CUST0492', 'CUST0493', 'CUST0494', 'CUST0495', 'CUST0496',
#  'CUST0497', 'CUST0498', 'CUST0499', 'CUST0500']
# Length: 500, dtype: str

# %%
cd
# Out:
#     Customer_ID   Customer_Name       City  Gender  Age
# 0      CUST0001    Aarav Sharma     Mumbai    Male   35
# 1      CUST0002    Vivaan Kumar    Gurgaon    Male   26
# 2      CUST0003    Aditya Singh     Mumbai    Male   55
# 3      CUST0004     Arjun Verma  Hyderabad    Male   19
# 4      CUST0005     Rahul Gupta     Mumbai    Male   32
# ..          ...             ...        ...     ...  ...
# 495    CUST0496    Naveen Patel     Mumbai  Female   23
# 496    CUST0497     Gaurav Jain    Kolkata    Male   20
# 497    CUST0498     Sumit Gupta    Gurgaon  Female   46
# 498    CUST0499    Vivek Tiwari    Kolkata    Male   41
# 499    CUST0500  Rajiv Malhotra  Bengaluru  Female   42
#
# [500 rows x 5 columns]
