# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Anish Kumar\Downloads\store_sales_data.csv")

# %%
df.head(5)
# Out:
#   Customer ID Customer Name Last Name Date of Birth     Sales  Year  \
# 0  CUST000001        Curtis    Krause    1973-11-29   3344.69  2023
# 1  CUST000002        Jeremy    Foster    1987-08-30  37094.41  2022
# 2  CUST000003         Ariel    Mccann    1980-12-15  35501.08  2023
# 3  CUST000004       Colleen   Maynard    1989-05-23   8969.33  2021
# 4  CUST000005          Gina    Holden    1957-12-31  35530.44  2021
#
#   Outlet Type City Type              Category of Goods Region  ...  \
# 0       Large    Tier 1                      Fast Food   East  ...
# 1      Medium    Tier 2                      Fast Food   East  ...
# 2       Large   Village            Electric Appliances  South  ...
# 3      Medium   Village                 Dairy Products   East  ...
# 4       Small   Village  Sessional Fruits & Vegetables   West  ...
#
#     Ship Date       Ship Mode        State Postal Code  Product ID  \
# 0  2020-04-18        Same Day  West Bengal      700001  PROD000001
# ...

# %%
df.tail(5)
# Out:
#       Customer ID Customer Name Last Name Date of Birth     Sales  Year  \
# 99995  CUST099996        Thomas     Adams    2018-02-02    254.35  2020
# 99996  CUST099997      Clifford    Dillon    1955-08-11    846.66  2019
# 99997  CUST099998         Kelly    Deleon    1991-02-27  12165.34  2019
# 99998  CUST099999         Katie     Moses    1990-10-21  41242.99  2019
# 99999  CUST100000        Jeremy     Combs    2016-12-27  47402.45  2019
#
#       Outlet Type City Type              Category of Goods Region  ...  \
# 99995       Large    Tier 1                      Furniture   East  ...
# 99996      Medium    Tier 2  Sessional Fruits & Vegetables  North  ...
# 99997       Large    Tier 2                      Furniture   East  ...
# 99998       Small    Tier 1                      Fast Food  North  ...
# 99999      Medium   Village                      Fast Food  North  ...
#
#         Ship Date       Ship Mode        State Postal Code  Product ID  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Customer ID        100000 non-null  str
#  1   Customer Name      100000 non-null  str
#  2   Last Name          100000 non-null  str
#  3   Date of Birth      100000 non-null  str
#  4   Sales              100000 non-null  float64
#  5   Year               100000 non-null  int64
#  6   Outlet Type        100000 non-null  str
#  7   City Type          100000 non-null  str
#  8   Category of Goods  100000 non-null  str
#  9   Region             100000 non-null  str
#  10  Country            100000 non-null  str
#  11  Segment            100000 non-null  str
#  12  Sales Date         100000 non-null  str
#  13  Order ID           100000 non-null  str
#  14  Order Date         100000 non-null  str
#  15  Ship Date          100000 non-null  str
# ...

# %%
df.describe()
# Out:
#                Sales           Year    Postal Code       Quantity  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    25084.410142    2020.999910  388985.180000       5.493760
# std     14403.187686       1.413757  184192.704685       2.876102
# min       100.570000    2019.000000  110001.000000       1.000000
# 25%     12618.030000    2020.000000  226001.000000       3.000000
# 50%     25134.695000    2021.000000  380001.000000       5.000000
# 75%     37575.850000    2022.000000  560001.000000       8.000000
# max     49999.890000    2023.000000  700001.000000      10.000000
#
#             Discount         Profit
# count  100000.000000  100000.000000
# mean        0.251320    3755.305114
# std         0.144324    2639.852035
# min         0.000000       6.520000
# 25%         0.130000    1651.105000
# 50%         0.250000    3317.450000
# 75%         0.380000    5363.845000
# max         0.500000   14563.670000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Customer Name', 'Last Name', 'Date of Birth', 'Sales',
#        'Year', 'Outlet Type', 'City Type', 'Category of Goods', 'Region',
#        'Country', 'Segment', 'Sales Date', 'Order ID', 'Order Date',
#        'Ship Date', 'Ship Mode', 'State', 'Postal Code', 'Product ID',
#        'Sub-Category', 'Product Name', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Customer ID          0
# Customer Name        0
# Last Name            0
# Date of Birth        0
# Sales                0
# Year                 0
# Outlet Type          0
# City Type            0
# Category of Goods    0
# Region               0
# Country              0
# Segment              0
# Sales Date           0
# Order ID             0
# Order Date           0
# Ship Date            0
# Ship Mode            0
# State                0
# Postal Code          0
# Product ID           0
# Sub-Category         0
# Product Name         0
# Quantity             0
# Discount             0
# Profit               0
# dtype: int64

# %%
df["Sales Date"] = pd.to_datetime(df["Sales Date"], format="%Y-%m-%d")

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], format="%Y-%m-%d")

# %%
df["Ship Date"] = pd.to_datetime(df["Ship Date"], format="%Y-%m-%d")

# %%
df.head()
# Out:
#   Customer ID Customer Name Last Name Date of Birth     Sales  Year  \
# 0  CUST000001        Curtis    Krause    1973-11-29   3344.69  2023
# 1  CUST000002        Jeremy    Foster    1987-08-30  37094.41  2022
# 2  CUST000003         Ariel    Mccann    1980-12-15  35501.08  2023
# 3  CUST000004       Colleen   Maynard    1989-05-23   8969.33  2021
# 4  CUST000005          Gina    Holden    1957-12-31  35530.44  2021
#
#   Outlet Type City Type              Category of Goods Region  ...  Ship Date  \
# 0       Large    Tier 1                      Fast Food   East  ... 2020-04-18
# 1      Medium    Tier 2                      Fast Food   East  ... 2021-01-11
# 2       Large   Village            Electric Appliances  South  ... 2020-08-16
# 3      Medium   Village                 Dairy Products   East  ... 2021-10-16
# 4       Small   Village  Sessional Fruits & Vegetables   West  ... 2019-01-25
#
#         Ship Mode        State Postal Code  Product ID Sub-Category  \
# ...
