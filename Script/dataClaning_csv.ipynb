# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\EXCEL\unclean_large.csv')

# %%
df
# Out:
#              Name    Age                 City  Salary Status   Join Date  \
# 0        Jonathan    N/A            Connieton    -802    Yes  2024-05-01
# 1           Rose   160.0             Moonton   249282    Yes  19/09/2025
# 2    Christopher   103.0          port alice   975635    Yes  28/07/2023
# 3           Mary     N/A                  N/A  842595     No  04/01/2021
# 4          David     N/A                  N/A  370494    Yes  2022-07-06
# 5           Tanya  102.0                  N/A   -4961    Yes  24/12/2024
# 6         Gregory    N/A                  N/A  496099    Yes         N/A
# 7         Edward   199.0                  N/A  858077     No         N/A
# 8          Wesley    N/A           West James   -1887    Yes  2023-10-23
# 9           Tanya  188.0                  N/A  206439     No         N/A
# 10        Morgan    -4.0   New Christiemouth   964524     No         N/A
# 11        Carrie   112.0            East John   -1298     No         N/A
# ...

# %%
df.head()
# Out:
#             Name    Age          City  Salary Status   Join Date Extra Column
# 0       Jonathan    NaN     Connieton    -802      Y  2024-05-01      Remove1
# 1          Rose   160.0      Moonton   249282      Y  19/09/2025      Remove2
# 2   Christopher   103.0   port alice   975635      y  28/07/2023      Remove3
# 3          Mary     NaN           NaN  842595      N  04/01/2021      Remove4
# 4         David     NaN           NaN  370494    Yes  2022-07-06      Remove5

# %%
df.tail()
# Out:
#         Name   Age         City  Salary Status   Join Date Extra Column
# 55    Teresa   NaN          NaN    -669      y  12/11/2024     Remove56
# 56   Patrick   NaN          NaN   -3227      N  2022-08-03     Remove57
# 57  Victoria   3.0   bakerbury   673403    Yes  2021-09-12     Remove58
# 58      John  72.0    bakerfurt    -441      N         NaN     Remove59
# 59   Lindsay   5.0     Johnton    -1379      n         NaN     Remove60

# %%
df.shape
# Out:
# (60, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          60 non-null     object
#  1   Age           37 non-null     float64
#  2   City          41 non-null     object
#  3   Salary        60 non-null     int64
#  4   Status        60 non-null     object
#  5   Join Date     35 non-null     object
#  6   Extra Column  60 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 3.4+ KB

# %%
df.describe()
# Out:
#               Age         Salary
# count   37.000000      60.000000
# mean    62.405405  267953.483333
# std     68.009582  345245.274450
# min     -4.000000   -4961.000000
# 25%      3.000000   -1892.000000
# 50%     43.000000   16253.000000
# 75%    112.000000  518895.250000
# max    199.000000  975635.000000

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Name', 'Age', 'City', 'Salary', 'Status', 'Join Date', 'Extra Column'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#              Name    Age                 City  Salary Status   Join Date  \
# 0        Jonathan    N/A            Connieton    -802    Yes  2024-05-01
# 1           Rose   160.0             Moonton   249282    Yes  19/09/2025
# 2    Christopher   103.0          port alice   975635    Yes  28/07/2023
# 3           Mary     N/A                  N/A  842595     No  04/01/2021
# 4          David     N/A                  N/A  370494    Yes  2022-07-06
# 5           Tanya  102.0                  N/A   -4961    Yes  24/12/2024
# 6         Gregory    N/A                  N/A  496099    Yes         N/A
# 7         Edward   199.0                  N/A  858077     No         N/A
# 8          Wesley    N/A           West James   -1887    Yes  2023-10-23
# 9           Tanya  188.0                  N/A  206439     No         N/A
# 10        Morgan    -4.0   New Christiemouth   964524     No         N/A
# 11        Carrie   112.0            East John   -1298     No         N/A
# ...

# %%
df.isnull().sum()
# Out:
# Name            0
# Age             0
# City            0
# Salary          0
# Status          0
# Join Date       0
# Extra Column    0
# dtype: int64

# %%
df["Age"] = df["Age"].fillna("N/A")
df["City"] = df["City"].fillna("N/A")
df["Join Date"] = df["Join Date"].fillna("N/A")

# %%
df["Status"] = df["Status"].replace({
    "y": "Yes",
    "n": "No"
})
df
# Out:
#              Name    Age                 City  Salary Status   Join Date  \
# 0        Jonathan    N/A            Connieton    -802    Yes  2024-05-01
# 1           Rose   160.0             Moonton   249282    Yes  19/09/2025
# 2    Christopher   103.0          port alice   975635    Yes  28/07/2023
# 3           Mary     N/A                  N/A  842595     No  04/01/2021
# 4          David     N/A                  N/A  370494    Yes  2022-07-06
# 5           Tanya  102.0                  N/A   -4961    Yes  24/12/2024
# 6         Gregory    N/A                  N/A  496099    Yes         N/A
# 7         Edward   199.0                  N/A  858077     No         N/A
# 8          Wesley    N/A           West James   -1887    Yes  2023-10-23
# 9           Tanya  188.0                  N/A  206439     No         N/A
# 10        Morgan    -4.0   New Christiemouth   964524     No         N/A
# 11        Carrie   112.0            East John   -1298     No         N/A
# ...

# %%
df["Salary"] = df["Salary"].replace("-", regex=False)
df
# Out:
# C:\Users\Anish Kumar\AppData\Local\Temp\ipykernel_4600\241888979.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df["Salary"] = df["Salary"].replace("-", regex=False)
#              Name    Age                 City  Salary Status   Join Date  \
# 0        Jonathan    NaN            Connieton    -802      Y  2024-05-01
# 1           Rose   160.0             Moonton   249282      Y  19/09/2025
# 2    Christopher   103.0          port alice   975635      y  28/07/2023
# 3           Mary     NaN                  NaN  842595      N  04/01/2021
# 4          David     NaN                  NaN  370494    Yes  2022-07-06
# 5           Tanya  102.0                  NaN   -4961      Y  24/12/2024
# 6         Gregory    NaN                  NaN  496099      Y         NaN
# 7         Edward   199.0                  NaN  858077      N         NaN
# ...

# %%
df["City"] = df["City"].std.title()
