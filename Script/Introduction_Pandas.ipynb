# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel(
    r"C:\EXCEL\product_details.xlsx"
)

# %%
df
# Out:
#                              Product ID Product Name     Category  \
# 0  9d3b5ef4-240c-4cc7-9ab7-b5466b94cbfb         goal       Sports
# 1  bde734cf-e2b3-4e9f-9d24-a3b62b90a469     shoulder       Sports
# 2  29661b3a-a87a-4969-a1fe-4ab8c4f2c0df         wait  Electronics
# 3  682b1a80-8955-410e-8a21-9f80882fdd4f         push  Electronics
# 4  2fefaf6e-759a-4c63-b0e6-c3f655dd50f1          tax     Clothing
# 5  d8a985fa-59d5-4b6a-8480-a93c84373081         town         Toys
# 6  564c0810-e5ca-444b-8823-a6f3ea734269         word  Electronics
# 7  cabe15df-bf9b-432d-9661-c860e712cada        local       Sports
# 8  997aed3b-1abf-43d7-806e-d6a60c933a52         born  Electronics
# 9  d0696e5f-6465-46c3-9faa-fe9e9f942db6       future     Clothing
#
#                           Brand   Price  Rating  Reviews Count  Stock  \
# 0             Velasquez-Vasquez  220.13     3.9           7646    259
# 1   George, Nelson and Mcdaniel  313.66     4.5            827    420
# ...

# %%
print(df.isnull())
print(df.isnull().sum())
# Out:
#    Product ID  Product Name  Category  Brand  Price  Rating  Reviews Count  \
# 0       False         False     False  False  False   False          False
# 1       False         False     False  False  False   False          False
# 2       False         False     False  False  False   False          False
# 3       False         False     False  False  False   False          False
# 4       False         False     False  False  False   False          False
# 5       False         False     False  False  False   False          False
# 6       False         False     False  False  False   False          False
# 7       False         False     False  False  False   False          False
# 8       False         False     False  False  False   False          False
# 9       False         False     False  False  False   False          False
#
#    Stock  Product Description  Release Date  Dimensions  Weight
# 0  False                False         False       False   False
# ...
